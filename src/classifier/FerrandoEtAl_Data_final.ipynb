# %% [markdown]
# Now we create a function which masks the last two words of the disease name (both words if there are only two)
# We will present this to the LLM and ask it to give use the masked words.
# Two correct words will count as a 'known entity', two incorrect words will count as an 'unknown entity'.
# Inbetween will count as a 'half-known entity' nd be dismissed form the analysis, as per Ferrando et al.

# %%
import goodfire
import os
import re
import pandas as pd
import json
from nltk import WordNetLemmatizer
from difflib import SequenceMatcher
import nest_asyncio
import asyncio
from tqdm import tqdm
from together import Together
import time
import logging
from datetime import datetime
from typing import List, Dict, Tuple
from langchain.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field
from tqdm.notebook import tqdm

# %%
api_key ='REDACTED'
client = goodfire.Client(api_key)
TOGETHER_API_KEY = 'REDACTED'
variant = 'meta-llama/Meta-Llama-3.1-8B-Instruct'
os.environ["OPENAI_API_KEY"] = "REDACTED"

# %% [markdown]
# ## Beware the Contrastive Trick
#
# In the contrastive trick we subtract the feature activiations of a 'known' entity from the feature activations of an unknown entity. We can sum or average the differences over a batch of such pairs, getting the most different features between each set. Negative features are those which indicate hallucination, positive features indicate non-hallucination.We can repeat this batched process over the entire data set and union the resulting features from each batch into a single distinct list of feature differences.
#
# BUT
#
# As per Ferrando et al, we want the features which are activated almost exclusively in one condition (known vs. unknown) but rarely or  never activate in the other condition. We are interested in exclusivity not scale.
#
# Simply summing the per-batch differences in activations is not well-suited to detecting exclusive features. Summation over subsets will highlight features that have large aggregate differences. This will include the exclusive features we seek, but will not isolate them. We wont know which if the differing features are alsmost exclusive to one class or other.
#
# So
#
# We follow the approach by Ferrando et al, see p4 of 'Do I know this entity?':
#
# ```
# For each latent, we obtain the fraction of the time that it is active (i.e. has a value greater than zero) on known and unknown entities respectively...Then, we take the difference, obtaining the latent separation scores
# ```
#
# In order to achieve this, we need to get the activated features from each and every prompt, we can't use the contrastive trick as per above.

# %% [markdown]
# ##  Chosen Datasets!
#
# 'The Human Disease Ontology' (HumanDO) which is freely available on the web and github:
#
# https://disease-ontology.org/
#
# https://github.com/DiseaseOntology/HumanDiseaseOntology/tree/main/src/ontology
#
# From the github site we can download the HumanDO.json file. Example content below:

# %%
# Example from HumanDO.json
with open('../classifier/data_classifier/HumanDO.json', 'r', encoding='utf-8') as file:
    data = json.load(file)
    # If the JSON structure has a top-level key containing the graph data,
    # you might need to access it like data['graphs'] or similar
    humando = data.get('graphs', [{}])[0].get('nodes', [])

humando[0]
# Out:
# {'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#  'lbl': 'angiosarcoma',
#  'type': 'CLASS',
#  'meta': {'definition': {'val': 'A vascular cancer that derives_from the cells that line the walls of blood vessels or lymphatic vessels.',
#    'xrefs': ['url:http://en.wikipedia.org/wiki/Hemangiosarcoma',
#     'url:https://en.wikipedia.org/wiki/Angiosarcoma',
#     'url:https://ncit.nci.nih.gov/ncitbrowser/ConceptReport.jsp?dictionary=NCI_Thesaurus&ns=ncit&code=C3088',
#     'url:https://www.ncbi.nlm.nih.gov/pubmed/23327728']},
#   'subsets': ['http://purl.obolibrary.org/obo/doid#DO_cancer_slim',
#    'http://purl.obolibrary.org/obo/doid#NCIthesaurus'],
#   'synonyms': [{'pred': 'hasExactSynonym', 'val': 'hemangiosarcoma'}],
#   'xrefs': [{'val': 'ICDO:9120/3'},
#    {'val': 'MESH:D006394'},
#    {'val': 'NCI:C3088'},
#    {'val': 'NCI:C9275'},
#    {'val': 'SNOMEDCT_US_2023_03_01:39000009'},
#    {'val': 'UMLS_CUI:C0018923'},
#    {'val': 'UMLS_CUI:C0854893'}],
#   'basicPropertyValues': [{'pred': 'http://www.geneontology.org/formats/oboInOwl#hasAlternativeId',
#     'val': 'DOID:267'},
#    {'pred': 'http://www.geneontology.org/formats/oboInOwl#hasAlternativeId',
#     'val': 'DOID:4508'},
#    {'pred': 'http://www.geneontology.org/formats/oboInOwl#hasOBONamespace',
#     'val': 'disease_ontology'}]}}

# %% [markdown]
# ## Helper Functions

# %%
def score_llm_response(llm_response, expected_words, missing_qty=2):
    """
    Score LLM response against expected words using flexible matching rules.
    
    Args:
        llm_response (str): String containing one or two words in any format
        expected_words (list): List of expected words (one or two)
        missing_qty (int): Number of words expected (1 or 2)
        
    Returns:
        int: Score (0, 1, or 2 for missing_qty=2; 0 or 1 for missing_qty=1) based on number of correct matches
    """
    def clean_word(word):
        """Convert to singular form and lowercase"""
        lemmatizer = WordNetLemmatizer()
        
        word = word.lower().strip()
        word = word.strip('"\'[](),.')  # Remove common punctuation
        
        word = lemmatizer.lemmatize(word, 'n')
        return word
    
    def words_match(word1, word2):
        """Check if words approximately match using sequence matcher"""
        word1 = clean_word(word1)
        word2 = clean_word(word2)
        
        ratio = SequenceMatcher(None, word1, word2).ratio()
        return ratio > 0.85  # Threshold for approximate matching
    
    def extract_words(llm_response, missing_qty):
        """Extract first two words from first sequence in various input formats"""
        # Split on common sequence separators like 'or', 'and', newlines
        sequences = re.split(r'\s+or\s+|\s+and\s+|\n', llm_response, flags=re.IGNORECASE)
        
        # Take only the first sequence
        first_sequence = sequences[0]
        
        # Remove any brackets, quotes, etc.
        first_sequence = re.sub(r'[\[\]\'"{},]', ' ', first_sequence)
        
        # Split on whitespace and filter out empty strings
        words = [word.strip() for word in first_sequence.split() if word.strip()]
        
        # Take first two non-empty words
        return words[:missing_qty]
    
    try:
        # if simply answering questions missing_qty is -1, but we mean '1'.
        if missing_qty == -1:
            missing_qty = 1

        # Validate missing_qty parameter
        if missing_qty not in [-1, 1, 2]:
            raise ValueError("missing_qty must be either 1 or 2")
            
        # Validate expected_words length matches missing_qty
        if len(expected_words) != missing_qty:
            raise ValueError(f"Expected {missing_qty} words but got {len(expected_words)} words")
        
        # Extract words from response string
        llm_words = extract_words(llm_response, missing_qty)
        
        if len(llm_words) < missing_qty:
            return 0  # Not enough words provided
            
        # Count matches (allowing for either order)
        matches = 0
        used_expected = set()
        used_llm = set()
        
        # Look for matches in any order
        for i, llm_word in enumerate(llm_words):
            for j, expected_word in enumerate(expected_words):
                if j not in used_expected and i not in used_llm:
                    if words_match(llm_word, expected_word):
                        matches += 1
                        used_expected.add(j)
                        used_llm.add(i)
                        break
        
        return matches
        
    except Exception as e:
        print(f"Error processing response: {e}")
        return 0

# %%
from tqdm import tqdm
from together import Together
import time

def query_to_llm_(records, provider="goodfire", missing_qty = 2):
    
    # Get data
    records_completed = []
    client_gf = goodfire.Client(api_key)
    client_tg = Together(api_key=TOGETHER_API_KEY)

    # loop over the data with tqdm progress bar
    for record in tqdm(records, desc="Processing records"):
    
        # Create query with instructions to LLM
        if missing_qty == 2:
            instruction = "Without preamble, give the two missing words as indicated by [Word A] and [Word B] in the following sentence. Return your answer as a python list:\n "
        elif missing_qty == 1:
            instruction = "Without preamble, give the missing word as indicated by [Word A] in the following sentence. Return your answer as a python list:\n "
        elif missing_qty == -1:
            instruction = "Without preamble, give the answer to the following question. Return your answer as a member of a python list:\n "

        else:
            print("No such quantity of missing words")
            return
            
        query = instruction + record['query']

        if provider == 'goodfire':
            
            # Simple rate limiting
            time.sleep(1.5)

            # Create a non-streaming completion using Goodfire
            response = client_gf.chat.completions.create(
                messages=[{"role": "user", "content": query}],
                model="meta-llama/Meta-Llama-3.1-8B-Instruct", # "meta-llama/Llama-3.3-70B-Instruct", "meta-llama/Meta-Llama-3.1-8B-Instruct"
            )
            llm_response = response.choices[0].message["content"]

        else:
            # call Together.ai

            try:
                response = client_tg.chat.completions.create(
                    model="meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo",
                    messages=[{"role": "user", "content": query}],
                    temperature=0.0,
                )
                llm_response = response.choices[0].message.content

            except Exception as e:
                llm_response = ''
                print(e)

        # Score LLM response
        score = score_llm_response(llm_response, expected_words=record['missing_words'], missing_qty=missing_qty)

        # Save results
        record['llm_response'] = llm_response
        record['score'] = score
        records_completed.append(record)

    return records_completed

# %%
# Enable nested event loops
nest_asyncio.apply()

# Configure logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f'async_performance_{datetime.now().strftime("%Y%m%d_%H%M%S")}.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger('query_processor')

class AsyncRateLimiter:
    """Async rate limiter using a semaphore and sliding window"""
    def __init__(self, rate_limit=100):
        self.semaphore = asyncio.Semaphore(rate_limit)
        self.request_times = []
        self.window_size = 60  # 1 minute window
        self.requests_per_minute = rate_limit
        self.lock = asyncio.Lock()
        self.logger = logging.getLogger('query_processor.rate_limiter')

    async def acquire(self):
        """Acquire rate limit token"""
        start_time = time.time()
        current_time = start_time
        
        async with self.lock:
            # Remove timestamps older than our window
            self.request_times = [t for t in self.request_times 
                                if current_time - t < self.window_size]
            
            # If we're at capacity, wait until we have room
            while len(self.request_times) >= self.requests_per_minute:
                wait_time = self.request_times[0] + self.window_size - current_time
                if wait_time > 0:
                    await asyncio.sleep(wait_time)
                current_time = time.time()
                self.request_times = [t for t in self.request_times 
                                    if current_time - t < self.window_size]
            
            self.request_times.append(current_time)
            await self.semaphore.acquire()

    async def release(self):
        """Release rate limit token"""
        self.semaphore.release()

async def query_goodfire(client, query, rate_limiter):
    """Make a rate-limited query to Goodfire with retries"""
    max_retries = 5
    initial_wait = 1
    
    for retry in range(max_retries):
        try:
            await rate_limiter.acquire()
            try:
                response = await client.chat.completions.create(
                    messages=[{"role": "user", "content": query}],
                    model="meta-llama/Meta-Llama-3.1-8B-Instruct",
                    temperature=0
                )
                return response.choices[0].message['content']
            finally:
                await rate_limiter.release()
        except Exception as e:
            if retry == max_retries - 1:
                logger.error(f"Max retries exceeded: {str(e)}")
                return ''
            wait_time = initial_wait * (2 ** retry)
            await asyncio.sleep(wait_time)
    
    return ''

async def process_record(record, client_gf, client_tg, rate_limiter, provider, missing_qty):
    """Process a single record"""
    # Create query with instructions
    if missing_qty == 2:
        instruction = "Without preamble, give the two missing words as indicated by [Word A] and [Word B] in the following sentence. Return your answer as a python list:\n "
    elif missing_qty == 1:
        instruction = "Without preamble, give the missing word as indicated by [Word A] in the following sentence. Return your answer as a python list:\n "
    elif missing_qty == -1:
        instruction = "Without preamble, give the answer to the following question. Return your answer as a member of a python list:\n "

    else:
        return None
        
    query = instruction + record['query']

    if provider == 'goodfire':
        llm_response = await query_goodfire(client_gf, query, rate_limiter)
    else:
        try:
            response = client_tg.chat.completions.create(
                model="meta-llama/Meta-Llama-3.1-8B-Instruct-Turbo",
                messages=[{"role": "user", "content": query}],
                temperature=0.0,
            )
            llm_response = response.choices[0].message.content
        except Exception as e:
            logger.error(f"Together API error: {str(e)}")
            llm_response = ''

    # Score LLM response
    score = score_llm_response(llm_response, expected_words=record['missing_words'], missing_qty=missing_qty)

    return {
        **record,
        'llm_response': llm_response,
        'score': score
    }

async def query_to_llm_async(ds_ncbi_processed, provider, missing_qty):
    """Asynchronous version of query_to_llm with robust rate limiting"""
    # Initialize clients and rate limiter
    client_gf = goodfire.AsyncClient(api_key)
    client_tg = Together(api_key=TOGETHER_API_KEY)
    rate_limiter = AsyncRateLimiter(rate_limit=40)  # Conservative rate limit
    
    # Process records concurrently
    tasks = [
        process_record(record, client_gf, client_tg, rate_limiter, provider, missing_qty)
        for record in ds_ncbi_processed
    ]
    
    ds_ncbi_completed = []
    for coro in tqdm(asyncio.as_completed(tasks), total=len(tasks), desc="Processing records"):
        result = await coro
        if result:
            ds_ncbi_completed.append(result)
    
    return ds_ncbi_completed

def query_to_llm(ds_ncbi_processed, provider="goodfire", missing_qty=-1):
    """Synchronous wrapper for the async implementation"""
    loop = asyncio.get_event_loop()
    return loop.run_until_complete(query_to_llm_async(ds_ncbi_processed, provider, missing_qty))

# %%
def get_feature_activations(client, variant, entity_names, k=50):
    """
    Simple synchronous version that processes one example at a time
    """
    feature_activations = []
    feature_library = set()



    for entity_name in tqdm(entity_names, desc="Processing entity_names"):
        try:
            inspector = client.features.inspect(
                [{"role": "user", "content": entity_name}],
                model=variant,
                #features=features
            )

            #  prepare to collect activated features
            entity_features=[]

            for activation in inspector.top(k=k):

                # keep our own library of all unique features and their id's
                feature_library.add((activation.feature.uuid, activation.feature.label))

                # record the feature id and its activation value for this entity 
                entity_features.append({'uuid':activation.feature.uuid, 'activation':activation.activation})

            feature_activations.append({'entity_name': entity_name, 'entity_features': entity_features})
            time.sleep(0.25)  # Simple rate limiting

        except Exception as e:
            print(f"Failed to process example: {str(e)}")
            continue
            
    return feature_activations, feature_library

# %%
# Fucntion to help select the unique known and unknown entities

def filter_duplicate_entities(known_list, unknown_list):
    # Create sets of entity names from both lists
    known_names = {record['entity_name'] for record in known_list}
    unknown_names = {record['entity_name'] for record in unknown_list}
    
    # Find duplicate names that appear in both lists
    duplicate_names = known_names.intersection(unknown_names)
    
    # Filter out records with duplicate names from both lists
    filtered_known = [record for record in known_list 
                     if record['entity_name'] not in duplicate_names]
    filtered_unknown = [record for record in unknown_list 
                       if record['entity_name'] not in duplicate_names]
    
    return filtered_known, filtered_unknown

# %%
# we need only 
# a) the disease label, which will our entity. 
#   - Some are long names with many words, we limit to disease entities with 2 words in their name.
# b) the meta definition, which will be used to generate questions and attributes.
# c) an id should we ever need to relate back to the original data

def parse_disease_entries(data, max_words=2):
    """
    Parse disease entries from Disease Ontology JSON format, filtering by word count in label.
    
    Args:
        data (list): List of disease entry dictionaries
        max_words (int, optional): Maximum number of words allowed in disease label. Defaults to 3.
        
    Returns:
        list: List of dictionaries containing parsed disease information with filtered labels
    """
    parsed_diseases = []
    
    for entry in data:
        label = entry.get('lbl', '')
        
        # Skip entries where label word count exceeds max_words
        if len(label.split()) > max_words:
            continue
            
        disease_info = {
            'entity': label,
            'description': '',
            'id': entry.get('id', '')
        }
        
        # Extract description from meta.definition if it exists
        meta = entry.get('meta', {})
        if 'definition' in meta:
            definition = meta['definition']
            if isinstance(definition, dict) and 'val' in definition:
                # Replace underscores with spaces in the description, as these appear annnoyingly common
                disease_info['description'] = definition['val'].replace('_', ' ')
        
        parsed_diseases.append(disease_info)
    
    return parsed_diseases

# %% [markdown]
# Process the records and then spit into train and test.

# %% [markdown]
# ## Anlayse Data for Features - Known vs Unknown
#
# We now need to see how well the LLM performs on the query, will it get fill in the blanks correctly?
# Waht are the features separation scores on the known vs unknown entities?
#
# Happily, we can use the functions we have already written on the Humand DO data.
#
# 1. Send each query to the LLM and score their knowledge o the disease entites
# 2. Use Goodfire to get the SAE features for the known vs unknown entities (not the queries, but the entities)
# 3. Calculate the separate scores for each feature on known vs unknown data

# %% [markdown]
# ## Create New Questions Using HumanDO data
#
# We need to do this precisely as per Ferrando et al.
# So we need to ask an LLM to do the following, as per an example using HumanDO...
# We will use GTP4-mini, as there will be thousands of questions, so many millions of tokens to process.
#
# ```
# Devise two questions with one word answers about this using this information only:
# "The disease Primary hyperoxaluria is a carbohydrate metabolic disorder characterized by impaired glyoxylate metabolism resulting in accumulation of oxalate throughout the body typically manifesting as kidney and bladder stones.",
#
# Your questions must start with "The disease Primary hyperoxaluria ...".
# Return your questions as a python list of dicts with the query and answer:
# [{query:"The disease....", answer:"..."}{query:"The disease....", answer:"..."}]
# ```

# %%
# Inspect sample
import pandas as pd
humando_parsed = pd.read_parquet('../classifier/data_classifier/humando_parsed_2Q.parquet')
humando_parsed = humando_parsed.to_dict('records')
humando_parsed = [{'entity': d['entity'], 'description': d['description'], 'id': d['id']} for d in humando_parsed]
humando_parsed[0:3]
# Out:
# [{'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816'},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116'},
#  {'entity': 'shrimp allergy',
#   'description': 'A crustacean allergy that has allergic trigger shrimp.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040001'}]

# %%
class QuestionAnswer(BaseModel):
    query: str = Field(..., description="The question about the disease")
    answer: str = Field(..., description="One-word answer to the question")

class QuestionGenerationAgent():
    """
    Agent responsible for generating questions and answers about diseases based on given descriptions.
    """
    async def run(self, llm, disease_records, red_herring=False):
        """
        Generate questions and answers based on the provided disease records.

        Args:
            llm: The language model to use for question generation
            disease_records (List[Dict]): List of disease records containing entity, description, and id

        Returns:
            tuple: A list of generated questions with answers and consumption details
        """
        try:
            tools = [{
                "name": "submit_questions",
                "description": "Submit generated questions and answers",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "question_answers": {
                            "type": "array",
                            "items": {
                                "type": "object",
                                "properties": {
                                    "query": {"type": "string"},
                                    "answer": {"type": "string"}
                                },
                                "required": ["query", "answer"]
                            },
                            "description": "List of questions and their answers"
                        }
                    },
                    "required": ["question_answers"]
                }
            }]

            all_questions = []

            for record in disease_records:

                # Create the prompt with the specific disease information
                if red_herring:
                
                    messages = [
                        ("system", "You are a phoney medical question generator."),
                        ("user", """
                        TASK: You will be devising two questions about this disease: '{entity}'. 
                        BUT, you will intentionally misspell the disease or use a spoonersim in the disease name.
                        Each question will have an answer of only one word. 
                        You may ONLY use the following information to devise the question.
                        <disease_information_to_be_used>
                        The disease {entity} is {description}
                        </disease_information_to_be_used>

                        Instructions for formulating the Question:
                        - Each of the two questions MUST end with these words: "the disease {entity} ?". 
                        - BUT, you will intentionally misspell the disease or use a spoonersim in the disease name.

                        Instructions for formulating the Answer:
                        - Only one word per answer, no more.
                        - Ensure the answers are not ambiguous and are complete within the one or two words permitted.
                        - Return the two questions with their respective answers as per the tool 'submit_questions'.""")
                    ]
                else:
                    messages = [
                        ("system", "You are a medical question generator."),
                        ("user", """
                        TASK: You will be devising two questions about this disease: '{entity}'. 
                        Each question will have an answer of only one word 
                        You may ONLY use the following information to devise the question.
                        <disease_information_to_be_used>
                        The disease {entity} is {description}
                        </disease_information_to_be_used>

                        Instructions for formulating the Question:
                        - Each of the two questions MUST end with these words: "the disease {entity} ?". 
                        - To repeat, you must form the questions so that they end with those words.

                        Instructions for formulating the Answer:
                        - Only one word per answer, no more.
                        - Ensure the answers are not ambiguous and are complete within the one word permitted.
                        - Return the two questions with their respective answers as per the tool 'submit_questions'.""")
                    ]
                prompt = ChatPromptTemplate.from_messages(messages).partial()

                # Create and invoke the chain
                chain = (prompt | llm.bind_tools(tools, tool_choice="submit_questions"))
                response = await chain.ainvoke(record)

                # Extract and validate questions
                func_args = response.additional_kwargs['tool_calls'][0]['function']['arguments']
                func_args_data = json.loads(func_args)
                
                # Validate each question-answer pair using Pydantic
                for qa_pair in func_args_data['question_answers']:
                    validated_qa = QuestionAnswer(**qa_pair)
                    all_questions.append(validated_qa.model_dump())

            return all_questions

        except json.JSONDecodeError as e:
            msg = f"Question Generation Agent Error: Invalid JSON: {str(e)}"
            print(msg)
            raise

        except KeyError as e:
            msg = f"Question Generation Agent Error: Missing key in JSON: {str(e)}"
            print(msg)
            raise

        except Exception as e:
            msg = f"Question Generation Agent Error: Unexpected error: {str(e)}"
            print(msg)
            raise

# %%
async def process_records(records, agent, llm, red_herring, batch_size=10):
    """
    Process records in simple batches with progress tracking.
    
    Args:
        records: List of disease records
        agent: QuestionGenerationAgent instance
        llm: Language model instance
        batch_size: How many records to process at once
    """
    processed_records = []
    
    # Create batches
    total_batches = (len(records) + batch_size - 1) // batch_size
    
    print(f"Processing {len(records)} records in {total_batches} batches")
    start_time = datetime.now()
    
    # Process each batch
    for i in tqdm(range(0, len(records), batch_size), desc="Processing batches"):
        batch = records[i:i + batch_size]
        batch_tasks = []
        
        # Process each record
        for record in batch:
            try:
                question_answers = await agent.run(llm, [record], red_herring)
                # Ensure questions is treated as a list
                if not isinstance(question_answers, list):
                    print(f"Warning: questions for {record['id']} is not a list: {question_answers}")
                    question_answers_list = [question_answers] if question_answers else []
                else:
                    question_answers_list = question_answers
                
                # record whether this is a red herring or not.
                record['red_herring']=red_herring

                # if red_herring, change the id, else we get dupes
                if red_herring:
                    record['id'] = f"{record['id']}_rh"

                processed_records.append({**record, "question_answers": question_answers_list})
            except Exception as e:
                print(f"Error processing record {record['id']}: {str(e)}")
                processed_records.append({**record, "question_answers": [], "error": str(e)})
        
    # Print summary
    end_time = datetime.now()
    duration = (end_time - start_time).total_seconds()
    print(f"\nProcessing completed in {duration:.2f} seconds")
    print(f"Successfully processed: {len(processed_records)} records")
    print(f"Average rate: {len(processed_records)/duration:.2f} records/second")
    
    return processed_records

# %%
import os

# Cell 1: Setup
from langchain_openai import ChatOpenAI

# Create the LLM instance
llm = ChatOpenAI(
    model="gpt-4o",  # or whatever model you're using
    temperature=0,
)

# Set up components
agent = QuestionGenerationAgent()

# Cell 2: Process records (use this code in a new cell)
# This works in Jupyter because it uses the notebook's event loop
# NOTE: red_herring tells us to create phoney entities or real ones.
humando_parsed_2Q = await process_records(humando_parsed, agent, llm, red_herring=False, batch_size=50)
# Out:
# Processing 4302 records in 87 batches
# Processing batches:   0%|          | 0/87 [00:00<?, ?it/s]
# 2025-01-19 00:26:32,072 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:32,946 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:33,828 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:34,936 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:36,350 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:37,222 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:38,246 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:39,288 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:40,238 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:41,212 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:42,005 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:43,013 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:43,882 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:45,345 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:46,545 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:47,316 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:48,141 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:49,372 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:50,148 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:51,200 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:52,903 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:53,813 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:54,660 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:55,881 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:56,675 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:57,593 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:58,895 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:26:59,762 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:00,965 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:02,194 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:03,430 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:04,998 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:05,790 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:06,839 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:08,378 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:09,226 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:10,172 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:11,145 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:12,539 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:13,786 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:14,595 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:15,517 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:16,498 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:17,398 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:18,101 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:19,105 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:20,201 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:21,121 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:22,317 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:23,173 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:23,982 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:24,776 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:25,774 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:26,659 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:28,074 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:32,598 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:33,532 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:34,515 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:35,296 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:36,239 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:37,687 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:38,935 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:39,973 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:40,892 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:41,768 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:42,807 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:43,659 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:44,754 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:45,631 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:46,718 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:48,444 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:49,326 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:50,376 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:51,378 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:52,594 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:53,578 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:54,907 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:55,779 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:56,702 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:57,593 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:58,434 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:27:59,225 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:00,342 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:01,060 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:02,026 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:02,942 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:03,905 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:04,907 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:05,994 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:07,175 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:08,190 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:09,097 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:10,005 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:10,936 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:11,942 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:13,028 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:13,855 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:14,886 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:15,906 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:16,807 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:17,641 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:18,676 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:19,604 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:20,724 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:21,651 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:22,767 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:23,793 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:24,848 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:25,772 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:26,749 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:27,758 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:28,792 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:30,860 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:31,858 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:32,938 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:35,855 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:36,790 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:37,758 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:47,129 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:48,135 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:49,126 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:50,196 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:51,352 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:52,418 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:53,402 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:54,235 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:55,353 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:56,408 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:57,412 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:28:58,702 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:00,502 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:01,389 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:02,848 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:03,993 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:05,251 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:06,382 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:10,101 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:11,013 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:12,230 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:13,460 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:14,591 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:15,553 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:16,483 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:17,636 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:18,534 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:19,424 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:20,364 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:21,331 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:22,418 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:23,440 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:24,296 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:25,238 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:26,106 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:26,981 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:27,845 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:28,680 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:29,403 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:30,289 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:31,312 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:32,313 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:33,331 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:34,215 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:36,171 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:37,101 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:38,205 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:39,119 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:39,917 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:41,020 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:42,158 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:43,388 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:44,550 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:45,678 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:46,674 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:47,675 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:49,187 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:50,302 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:51,315 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:52,129 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:53,135 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:55,804 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:56,906 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:57,767 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:58,762 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:29:59,854 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:01,036 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:01,831 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:02,968 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:03,740 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:04,740 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:05,791 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:06,729 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:07,833 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:09,020 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:10,174 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:11,072 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:12,102 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:13,109 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:14,181 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:17,702 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:18,694 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:19,754 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:20,594 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:21,783 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:22,701 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:23,560 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:24,541 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:25,593 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:26,434 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:27,504 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:28,423 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:29,610 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:30,615 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:31,474 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:32,685 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:34,079 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:35,048 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:36,037 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:37,271 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:38,581 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:39,464 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:41,047 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:42,297 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:43,510 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:44,522 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:45,776 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:46,817 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:47,793 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:48,765 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:49,800 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:50,992 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:51,987 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:52,940 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:54,417 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:57,341 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:58,619 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:30:59,816 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:00,659 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:01,532 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:02,396 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:06,890 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:07,770 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:09,470 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:10,617 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:11,612 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:12,476 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:13,737 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:14,615 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:16,128 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:18,129 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:19,522 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:20,447 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:21,272 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:22,401 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:23,351 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:24,237 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:25,900 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:27,118 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:28,158 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:29,085 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:29,984 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:33,553 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:34,586 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:35,516 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:36,374 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:37,823 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:38,982 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:40,027 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:44,700 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:45,737 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:46,935 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:47,886 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:49,203 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:50,518 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:51,485 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:52,694 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:53,997 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:55,035 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:56,174 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:56,960 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:57,934 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:58,876 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:31:59,842 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:00,827 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:01,732 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:02,632 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:03,556 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:04,433 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:05,483 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:06,796 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:07,788 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:08,670 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:09,402 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:10,659 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:11,667 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:12,608 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:14,261 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:15,333 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:16,279 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:17,429 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:18,342 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:19,106 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:19,949 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:21,263 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:22,468 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:23,380 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:24,766 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:25,783 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:27,017 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:27,846 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:28,810 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:30,053 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:31,166 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:32,288 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:33,138 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:34,060 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:35,062 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:36,050 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:37,002 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:38,065 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:40,225 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:41,176 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:42,193 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:43,045 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:44,026 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:45,184 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:46,365 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:47,450 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:48,700 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:49,623 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:50,573 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:51,639 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:52,522 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:53,527 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:54,469 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:56,135 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:57,302 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:58,320 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:32:59,213 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:03,075 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:04,204 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:05,692 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:07,073 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:08,117 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:08,929 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:10,325 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:11,578 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:12,505 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:13,452 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:15,782 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:17,078 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:18,516 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:19,470 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:20,552 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:21,422 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:22,506 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:23,766 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:24,917 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:26,544 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:27,453 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:28,853 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:29,644 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:30,477 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:31,803 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:32,836 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:33,904 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:34,931 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:35,948 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:37,150 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:38,372 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:39,480 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:40,370 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:41,425 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:42,583 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:43,764 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:44,837 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:45,588 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:46,726 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:47,612 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:48,793 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:49,655 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:50,687 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:51,422 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:52,542 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:53,234 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:54,258 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:55,090 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:56,106 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:57,146 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:57,831 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:58,780 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:33:59,740 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:34:00,810 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:34:01,960 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:34:02,767 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 00:34:03,761 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# ...
# 2025-01-19 01:45:32,371 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:33,178 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:34,745 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:35,706 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:36,537 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:37,347 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:38,336 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:39,309 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:40,406 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:41,573 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:42,463 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:43,598 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:44,867 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:45,813 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:46,792 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:47,897 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:48,747 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:49,948 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:51,034 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:51,942 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:52,834 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:53,719 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:54,537 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:55,527 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:56,685 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:57,696 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:58,638 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:45:59,425 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:00,411 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:01,403 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:02,696 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:03,629 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:04,592 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:05,516 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:06,349 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:07,560 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:08,529 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:09,629 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:10,551 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:12,221 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:13,440 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:14,358 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:15,277 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:16,264 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:17,625 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:18,629 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:20,005 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:20,949 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:22,050 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:23,088 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:23,993 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:24,951 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:25,814 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:26,644 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:27,879 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:28,765 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:29,754 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:30,663 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:31,536 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:32,682 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:33,466 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:34,724 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:35,663 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:36,759 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:37,811 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:38,753 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:39,612 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:40,385 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:41,380 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:42,344 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:43,118 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:44,334 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:45,007 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:45,816 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:46,653 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:47,623 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:48,545 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:49,432 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:50,897 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:51,592 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:52,632 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:53,830 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:54,780 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:55,587 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:56,593 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:57,502 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:46:58,592 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:00,131 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:01,070 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:02,017 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:02,987 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:04,095 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:05,166 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:07,220 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:08,136 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:09,161 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:10,131 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:12,135 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:13,137 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:13,988 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:14,654 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:15,704 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:16,508 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:17,515 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:18,534 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:19,346 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:20,029 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:20,767 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:21,542 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:22,350 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:23,324 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:24,159 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:25,145 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:26,708 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:27,597 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:28,816 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:29,575 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:30,542 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:31,321 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:33,052 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:33,863 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:34,546 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:35,217 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:36,349 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:37,119 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:37,918 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:38,920 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:39,651 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:41,116 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:41,834 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:42,681 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing completed in 4872.02 seconds
# Successfully processed: 4302 records
# Average rate: 0.88 records/second

# %%
import random
random.choices(humando_parsed_2Q, k=3)
# Out:
# [{'entity': 'IDH-wildtype glioblastoma',
#   'description': 'A glioblastoma that is characterized by high cellularity, high mitotic activity, necrosis or microvascular proliferation and that lacks mutations in IDH genes.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0080878',
#   'red_herring': False,
#   'question_answers': [{'query': 'What type of cellularity characterizes the disease IDH-wildtype glioblastoma ?',
#     'answer': 'High'},
#    {'query': 'What type of activity is high in the disease IDH-wildtype glioblastoma ?',
#     'answer': 'Mitotic'}]},
#  {'entity': 'lip disease',
#   'description': 'A mouth disease located in the lip.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_9297',
#   'red_herring': False,
#   'question_answers': [{'query': 'Where is the disease lip disease located in the body for the disease lip disease ?',
#     'answer': 'lip'},
#    {'query': 'What type of disease is the disease lip disease ?',
#     'answer': 'mouth'}]},
#  {'entity': 'osteomalacia',
#   'description': 'A bone remodeling disease that has material basis in a vitamin D deficiency which results in softening located in bone.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_10573',
#   'red_herring': False,
#   'question_answers': [{'query': 'What vitamin deficiency is the material basis for the disease osteomalacia ?',
#     'answer': 'D'},
#    {'query': 'What type of disease is the disease osteomalacia ?',
#     'answer': 'Bone'}]}]

# %%
# get some red herrings
import math
agent = QuestionGenerationAgent()
humando_parsed_rd = random.choices(humando_parsed, k=200)
humando_parsed_2Q_rh = await process_records(humando_parsed_rd, agent, llm, red_herring=True, batch_size=50)
# Out:
# Processing 200 records in 4 batches
# Processing batches:   0%|          | 0/4 [00:00<?, ?it/s]
# 2025-01-19 01:47:43,652 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:44,442 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:45,341 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:46,800 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:47,692 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:48,576 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:52,149 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:53,088 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:53,945 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:55,154 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:55,996 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:56,856 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:57,824 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:58,829 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:47:59,748 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:00,644 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:01,914 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:02,788 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:03,914 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:05,436 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:06,892 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:08,536 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:09,615 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:10,570 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:11,667 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:12,762 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:13,705 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:14,825 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:15,841 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:17,179 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:22,308 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:23,350 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:24,477 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:25,417 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:26,242 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:27,148 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:28,240 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:29,046 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:32,038 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:32,935 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:33,992 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:35,037 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:36,245 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:37,698 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:38,571 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:40,386 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:41,369 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:42,288 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:43,314 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:44,361 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:45,394 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:46,598 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:47,532 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:48,577 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:49,452 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:50,619 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:51,514 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:52,541 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:53,629 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:54,790 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:55,731 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:56,817 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:48:58,130 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:02,282 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:03,284 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:04,639 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:05,722 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:06,821 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:07,951 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:08,772 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:09,976 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:10,828 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:11,638 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:12,478 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:13,349 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:14,245 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:15,535 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:16,694 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:17,624 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:19,533 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:20,469 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:21,283 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:22,407 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:23,315 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:24,235 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:25,383 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:26,349 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:27,540 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:28,809 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:29,816 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:30,770 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:31,732 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:40,961 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:42,477 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:43,482 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:44,543 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:45,543 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:46,672 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:47,823 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:48,952 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:49,769 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:50,954 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:51,893 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:52,816 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:53,721 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:54,662 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:55,898 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:56,819 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:58,047 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:49:59,357 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:00,432 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:01,352 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:02,201 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:04,302 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:05,195 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:06,069 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:07,109 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:08,466 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:09,282 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:10,230 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:11,211 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:12,067 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:13,387 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:14,181 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:15,124 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:16,177 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:20,096 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:21,119 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:23,140 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:24,669 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:25,884 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:26,751 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:27,729 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:28,726 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:30,292 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:31,214 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:32,346 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:33,277 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:34,312 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:35,242 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:36,588 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:37,470 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:38,399 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:39,532 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:40,836 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:41,747 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:42,711 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:43,583 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:44,486 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:45,590 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:46,528 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:47,619 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:48,650 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:52,677 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:53,614 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:54,602 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:55,898 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:56,818 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:57,898 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:58,753 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:50:59,675 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:00,655 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:01,792 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:02,933 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:03,982 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:04,966 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:05,930 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:06,827 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:08,595 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:09,658 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:10,765 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:11,684 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:12,604 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:13,522 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:14,756 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:15,666 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:16,412 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:17,999 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:18,912 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:19,922 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:21,128 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:22,374 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:23,348 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:24,281 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:25,118 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:26,229 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:27,058 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:28,089 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:29,110 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:30,165 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:31,468 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:32,414 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:33,259 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:34,111 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:35,568 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:36,666 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:38,155 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:39,736 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:40,848 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2025-01-19 01:51:41,916 - httpx - INFO - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Processing completed in 239.13 seconds
# Successfully processed: 200 records
# Average rate: 0.84 records/second

# %%
# Add the two lists together
humando_parsed_2Q = humando_parsed_2Q + humando_parsed_2Q_rh

# %%
pd.DataFrame(humando_parsed_2Q).to_parquet('../classifier/data_classifier/humando_parsed_3Q.parquet')

#View an example
humando_parsed_2Q[1000]
# Out:
# {'entity': 'holoprosencephaly 5',
#  'description': 'A holoprosencephaly that has material basis in heterozygous mutation in the ZIC2 gene on chromosome 13q32.',
#  'id': 'http://purl.obolibrary.org/obo/DOID_0110878',
#  'red_herring': False,
#  'question_answers': [{'query': 'What gene mutation is associated with the disease holoprosencephaly 5 ?',
#    'answer': 'ZIC2'},
#   {'query': 'On which chromosome is the mutation found in the disease holoprosencephaly 5 ?',
#    'answer': '13q32'}]}

# %%
# Pick up from saved data

humando_parsed_2Q = pd.read_parquet('../classifier/data_classifier/humando_parsed_3Q.parquet')
humando_parsed_2Q = humando_parsed_2Q.to_dict('records')
humando_parsed_2Q[0:4]
# Out:
# [{'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'question_answers': array([{'answer': 'Vascular', 'query': 'What type of cancer is the disease angiosarcoma ?'},
#          {'answer': 'Lining', 'query': 'From which cells does the disease angiosarcoma derive ?'}],
#         dtype=object)},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'question_answers': array([{'answer': 'corneal', 'query': 'What type of disease is the disease pterygium ?'},
#          {'answer': 'triangular', 'query': 'What type of tissue growth characterizes the disease pterygium ?'}],
#         dtype=object)},
#  {'entity': 'shrimp allergy',
#   'description': 'A crustacean allergy that has allergic trigger shrimp.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040001',
#   'red_herring': False,
#   'question_answers': array([{'answer': 'crustacean', 'query': 'What type of allergy is the disease shrimp allergy ?'},
#          {'answer': 'shrimp', 'query': 'What is the allergic trigger in the disease shrimp allergy ?'}],
#         dtype=object)},
#  {'entity': 'aspirin allergy',
#   'description': 'A drug allergy that has allergic trigger acetylsalicylic acid.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040002',
#   'red_herring': False,
#   'question_answers': array([{'answer': 'Drug', 'query': 'What type of allergy is the disease aspirin allergy ?'},
#          {'answer': 'Acetylsalicylic', 'query': 'What is the allergic trigger for the disease aspirin allergy ?'}],
#         dtype=object)}]

# %%
def convert_format(record):
    """
    Convert records to the format required by previous functions.
    
    Args:
        record (dict): Input record with question_answers field
        
    Returns:
        list: List of transformed records
    """
    # Create base record without question_answers
    base_record = {
        'entity': record['entity'],
        'description': record['description'],
        'id': record['id'],
        'red_herring': record['red_herring']
    }
    
    # Create a new record for each question-answer pair
    transformed_records = []
    for qa in record['question_answers']:
        new_record = base_record.copy()
        new_record['query'] = qa['query']
        new_record['missing_words'] = [qa['answer']]
        transformed_records.append(new_record)
    
    return transformed_records

# %%
humando_parsed_1Q = []
for record in humando_parsed_2Q:
    humando_parsed_1Q.extend(convert_format(record))

# %%
# inspect sample
# we expect two queries, i.e. two records, per id.
# We expect the missing word, [Word A], to be the last word in all queries, i.e. the answer.
humando_parsed_1Q[0:4]
# Out:
# [{'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'query': 'What type of cancer is the disease angiosarcoma ?',
#   'missing_words': ['Vascular']},
#  {'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'query': 'From which cells does the disease angiosarcoma derive ?',
#   'missing_words': ['Lining']},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'query': 'What type of disease is the disease pterygium ?',
#   'missing_words': ['corneal']},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'query': 'What type of tissue growth characterizes the disease pterygium ?',
#   'missing_words': ['triangular']}]

# %% [markdown]
# Now the data is in the same format as previously we can use same functions.
# We will have twice as many records to process, so 8000+ calls to Goodfire.
# Let's process the records.

# %%
import re

humando_parsed_1Q_completed_tg = query_to_llm_(humando_parsed_1Q, provider='together', missing_qty=-1)
# Out:
# Processing records:   0%|          | 0/9004 [00:00<?, ?it/s]

# %%
# inspect sample
humando_parsed_1Q_completed_tg[0:4]
# Out:
# [{'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'query': 'What type of cancer is the disease angiosarcoma ?',
#   'missing_words': ['Vascular'],
#   'llm_response': "['Sarcoma']",
#   'score': 0},
#  {'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'query': 'From which cells does the disease angiosarcoma derive ?',
#   'missing_words': ['Lining'],
#   'llm_response': "['endothelial cells']",
#   'score': 0},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'query': 'What type of disease is the disease pterygium ?',
#   'missing_words': ['corneal'],
#   'llm_response': "['Ocular', 'Chronic', 'Degenerative']",
#   'score': 0},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'query': 'What type of tissue growth characterizes the disease pterygium ?',
#   'missing_words': ['triangular'],
#   'llm_response': "['fibrovascular']",
#   'score': 0}]

# %% [markdown]
# ## But does an LLM agree with the answers?
#
# The Fuzzy answer matcher may not be perfect, let's also get an LLM's opinion on whther the llm_resposne is acceptable given the answer_expected and query.

# %%
from pydantic import BaseModel, Field
from typing import List, Dict, Any
import json
from langchain.prompts import ChatPromptTemplate

class QueryEvaluation(BaseModel):
    entity: str
    description: str
    id: str
    red_herring: bool
    query: str
    missing_words: List[str]
    llm_response: str
    score: int
    llm_response_opinion: int = 0

class ResponseEvaluationAgent:
    """
    Agent responsible for evaluating LLM responses against expected answers for disease-related questions.
    """
    async def run(self, llm, evaluation_records: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
        """
        Evaluate LLM responses for disease-related questions.

        Args:
            llm: The language model to use for evaluation
            evaluation_records: List of records containing queries, responses, and expected answers

        Returns:
            List[Dict]: The evaluated records with LLM opinions added
        """
        try:
            tools = [{
                "name": "submit_evaluation",
                "description": "Submit evaluation of LLM response",
                "parameters": {
                    "type": "object",
                    "properties": {
                        "is_acceptable": {
                            "type": "integer",
                            "description": "1 if the response is acceptable, 0 if not",
                            "enum": [0, 1]
                        }
                    },
                    "required": ["is_acceptable"]
                }
            }]

            evaluated_records = []

            for record in evaluation_records:
                messages = [
                    ("system", "You are a medical response evaluator."),
                    ("user", """
                    TASK: Evaluate if the LLM's response is an acceptable answer to the query.
                    
                    Context:
                    Disease: {entity}
                    Description: {description}
                    
                    Query: {query}
                    Expected answer word: {missing_words}
                    LLM's response: {llm_response}
                    
                    Instructions:
                    1. Consider if the LLM's response conveys the same meaning as the expected answer
                    2. The response should be evaluated based on medical accuracy and the disease description
                    3. Return 1 if acceptable, 0 if not acceptable
                    
                    Evaluate and submit using the 'submit_evaluation' tool.
                    """)
                ]
                
                prompt = ChatPromptTemplate.from_messages(messages)
                
                # Create and invoke the chain
                chain = (prompt | llm.bind_tools(tools, tool_choice="submit_evaluation"))
                response = await chain.ainvoke(record)
                
                # Extract evaluation
                func_args = response.additional_kwargs['tool_calls'][0]['function']['arguments']
                evaluation_result = json.loads(func_args)
                
                # Create evaluated record
                evaluated_record = record.copy()
                evaluated_record['llm_response_opinion'] = evaluation_result['is_acceptable']
                
                # Validate using Pydantic
                validated_record = QueryEvaluation(**evaluated_record)
                evaluated_records.append(validated_record.model_dump())

            return evaluated_records

        except json.JSONDecodeError as e:
            msg = f"Response Evaluation Agent Error: Invalid JSON: {str(e)}"
            print(msg)
            raise

        except KeyError as e:
            msg = f"Response Evaluation Agent Error: Missing key in JSON: {str(e)}"
            print(msg)
            raise

        except Exception as e:
            msg = f"Response Evaluation Agent Error: Unexpected error: {str(e)}"
            print(msg)
            raise

# %%
import asyncio
import nest_asyncio
from typing import List
import math
from tqdm.notebook import tqdm

# Enable asyncio in Jupyter
nest_asyncio.apply()

async def process_in_chunks(evaluator, llm, records: List[dict], chunk_size: int = 10):
    """Process records in chunks to avoid overwhelming the LLM service"""
    chunks = [records[i:i + chunk_size] for i in range(0, len(records), chunk_size)]
    all_results = []
    
    # Use tqdm with total number of chunks
    pbar = tqdm(total=len(chunks), desc="Processing chunks", unit="chunk")
    
    for chunk in chunks:
        chunk_results = await evaluator.run(llm, chunk)
        all_results.extend(chunk_results)
        pbar.update(1)
        
        # Optional: Add a small delay between chunks to avoid rate limits
        await asyncio.sleep(0.1)
    
    pbar.close()
    return all_results

# %%
from langchain_openai import ChatOpenAI

# Create the LLM instance
llm = ChatOpenAI(
    model="gpt-4o",  # or whatever model you're using
    temperature=0,
)

# Initialize your evaluator and llm objects first
evaluator = ResponseEvaluationAgent()

# Then run the processing
async def main():
    results = await process_in_chunks(evaluator, llm, humando_parsed_1Q_completed_tg, chunk_size=50)
    return results

# Execute in Jupyter
humando_parsed_1Q_completed_tg_temp = asyncio.run(main())
# Out:
# Processing chunks:   0%|          | 0/181 [00:00<?, ?chunk/s]

# %%
# save progress

pd.DataFrame(humando_parsed_1Q_completed_tg_temp).to_parquet('../classifier/data_classifier/humando_parsed_3Q_completed_tg.parquet')

# %%
# load progress
import pandas as pd
humando_parsed_1Q_completed_tg = pd.read_parquet('../classifier/data_classifier/humando_parsed_3Q_completed_tg.parquet')
humando_parsed_1Q_completed_tg = humando_parsed_1Q_completed_tg.to_dict('records')

# %% [markdown]
# We now have two questions per record, i.e. two records per id.
# We need to group these by id in order to score each entity as having 0, 1, or 2 attributes correctly named by the LLM.
# So, a new scoring function...

# %%
# We need a fuction to score split data

def calculate_combined_scores(split_data, score_type='score'):
    """
    Calculate scores for the original queries based on their split versions.
    
    Args:
        split_data (list): List of dictionaries containing split queries with individual scores
        
    Returns:
        tuple: (total_score_2, total_score_1, total_score_0) counts for queries where 
               2, 1, or 0 words were correctly guessed
    """
    # Group the split queries by their ID
    query_scores = {}
    for item in split_data:
        query_id = item['id']
        if query_id not in query_scores:
            query_scores[query_id] = []
        query_scores[query_id].append(item[score_type])
    
    # Count queries based on combined scores, start at zero
    score_2 = 0  # Both words correct
    score_1 = 0  # One word correct
    score_0 = 0  # No words correct

    for query_id, scores in query_scores.items():
        # Each query should have exactly 2 scores (Word A and Word B)
        assert len(scores) == 2, f"Query {query_id} has {len(scores)} scores instead of 2"
        
        # Sum the individual scores for the query
        total_correct = sum(scores)

        if total_correct == 2:  # Both words correctgit add src/classifier/FerrandoEtAl_Data_final.ipynb
            score_2 += 1
        elif total_correct == 1:  # One word correct
            score_1 += 1
            
        else:  # No words correct
            score_0 += 1
    
    return score_0, score_1, score_2

# %%
humando_parsed_1Q_completed_tg[0:4]
# Out:
# [{'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'query': 'What type of cancer is the disease angiosarcoma ?',
#   'missing_words': array(['Vascular'], dtype=object),
#   'llm_response': "['Sarcoma']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'query': 'From which cells does the disease angiosarcoma derive ?',
#   'missing_words': array(['Lining'], dtype=object),
#   'llm_response': "['endothelial cells']",
#   'score': 0,
#   'llm_response_opinion': 1},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'query': 'What type of disease is the disease pterygium ?',
#   'missing_words': array(['corneal'], dtype=object),
#   'llm_response': "['Ocular', 'Chronic', 'Degenerative']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'query': 'What type of tissue growth characterizes the disease pterygium ?',
#   'missing_words': array(['triangular'], dtype=object),
#   'llm_response': "['fibrovascular']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'shrimp allergy',
#   'description': 'A crustacean allergy that has allergic trigger shrimp.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040001',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease shrimp allergy ?',
#   'missing_words': array(['crustacean'], dtype=object),
#   'llm_response': "['IgE-mediated allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'shrimp allergy',
#   'description': 'A crustacean allergy that has allergic trigger shrimp.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040001',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease shrimp allergy ?',
#   'missing_words': array(['shrimp'], dtype=object),
#   'llm_response': "['Tropomyosin']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'aspirin allergy',
#   'description': 'A drug allergy that has allergic trigger acetylsalicylic acid.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040002',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease aspirin allergy ?',
#   'missing_words': array(['Drug'], dtype=object),
#   'llm_response': "['Aspirin Exacerbated Respiratory Disease (AERD) is a type of non-allergic hypersensitivity reaction, but it is often referred to as an aspirin allergy due to its similar symptoms and treatment. However, it is not a true allergic reaction, but rather an intolerance to the drug. It is often associated with an overproduction of leukotrienes, which are inflammatory chemicals in the body.']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'aspirin allergy',
#   'description': 'A drug allergy that has allergic trigger acetylsalicylic acid.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040002',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease aspirin allergy ?',
#   'missing_words': array(['Acetylsalicylic'], dtype=object),
#   'llm_response': "['Salicylate']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'benzylpenicillin allergy',
#   'description': 'A beta-lactam allergy that has allergic trigger benzylpenicillin.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040003',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease benzylpenicillin allergy ?',
#   'missing_words': array(['beta-lactam'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction', 'Type 1 hypersensitivity reaction']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'benzylpenicillin allergy',
#   'description': 'A beta-lactam allergy that has allergic trigger benzylpenicillin.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040003',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease benzylpenicillin allergy ?',
#   'missing_words': array(['benzylpenicillin'], dtype=object),
#   'llm_response': "['Penicillin']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'amoxicillin allergy',
#   'description': 'A beta-lactam allergy that has allergic trigger amoxicillin.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040004',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease amoxicillin allergy ?',
#   'missing_words': array(['beta-lactam'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction', 'Type I hypersensitivity reaction']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'amoxicillin allergy',
#   'description': 'A beta-lactam allergy that has allergic trigger amoxicillin.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040004',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease amoxicillin allergy ?',
#   'missing_words': array(['amoxicillin'], dtype=object),
#   'llm_response': "['Penicillin']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'ceftriaxone allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger ceftriaxone.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040005',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease ceftriaxone allergy ?',
#   'missing_words': array(['Cephalosporin'], dtype=object),
#   'llm_response': "['Penicillin allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'ceftriaxone allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger ceftriaxone.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040005',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease ceftriaxone allergy ?',
#   'missing_words': array(['Ceftriaxone'], dtype=object),
#   'llm_response': "['Ceftriaxone']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'carbamazepine allergy',
#   'description': 'A drug allergy that has allergic trigger carbamazepine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040006',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease carbamazepine allergy ?',
#   'missing_words': array(['carbamazepine'], dtype=object),
#   'llm_response': "['carbamazepine']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'carbamazepine allergy',
#   'description': 'A drug allergy that has allergic trigger carbamazepine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040006',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease carbamazepine allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction', 'Type IV hypersensitivity']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'abacavir allergy',
#   'description': 'A drug allergy that has allergic trigger abacavir.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040007',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease abacavir allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction', 'Immune-mediated reaction']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'abacavir allergy',
#   'description': 'A drug allergy that has allergic trigger abacavir.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040007',
#   'red_herring': False,
#   'query': 'What is the trigger for the disease abacavir allergy ?',
#   'missing_words': array(['abacavir'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction to abacavir is triggered by a genetic variation in the HLA-B*5701 allele.']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'isoniazide allergy',
#   'description': 'A drug allergy that has allergic trigger isoniazide.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040008',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease isoniazide allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Type IV hypersensitivity reaction']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'isoniazide allergy',
#   'description': 'A drug allergy that has allergic trigger isoniazide.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040008',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease isoniazide allergy ?',
#   'missing_words': array(['isoniazide'], dtype=object),
#   'llm_response': "['Isoniazid']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'lidocaine allergy',
#   'description': 'A drug allergy that has allergic trigger lidocaine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040009',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease lidocaine allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Local anesthetic allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'lidocaine allergy',
#   'description': 'A drug allergy that has allergic trigger lidocaine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040009',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease lidocaine allergy ?',
#   'missing_words': array(['lidocaine'], dtype=object),
#   'llm_response': "['Lidocaine']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'mepivacaine allergy',
#   'description': 'A drug allergy that has allergic trigger mepivacaine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040010',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease mepivacaine allergy ?',
#   'missing_words': array(['Drug'], dtype=object),
#   'llm_response': "['Local anesthetic allergy']",
#   'score': 0,
#   'llm_response_opinion': 1},
#  {'entity': 'mepivacaine allergy',
#   'description': 'A drug allergy that has allergic trigger mepivacaine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040010',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease mepivacaine allergy ?',
#   'missing_words': array(['Mepivacaine'], dtype=object),
#   'llm_response': "['mepivacaine']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'phenobarbital allergy',
#   'description': 'A drug allergy that has allergic trigger phenobarbital.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040011',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease phenobarbital allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'phenobarbital allergy',
#   'description': 'A drug allergy that has allergic trigger phenobarbital.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040011',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease phenobarbital allergy ?',
#   'missing_words': array(['phenobarbital'], dtype=object),
#   'llm_response': "['Phenobarbital']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'phenytoin allergy',
#   'description': 'A drug allergy that has allergic trigger phenytoin.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040012',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease phenytoin allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction', 'Type IV hypersensitivity reaction']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'phenytoin allergy',
#   'description': 'A drug allergy that has allergic trigger phenytoin.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040012',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease phenytoin allergy ?',
#   'missing_words': array(['phenytoin'], dtype=object),
#   'llm_response': "['hydantoin']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'ranitidine allergy',
#   'description': 'A drug allergy that has allergic trigger ranitidine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040013',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease ranitidine allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'ranitidine allergy',
#   'description': 'A drug allergy that has allergic trigger ranitidine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040013',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease ranitidine allergy ?',
#   'missing_words': array(['ranitidine'], dtype=object),
#   'llm_response': "['Ranitidine']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'corticosteroid allergy',
#   'description': 'A drug allergy that has allergic trigger corticosteroid.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040014',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease corticosteroid allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Contact dermatitis']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'corticosteroid allergy',
#   'description': 'A drug allergy that has allergic trigger corticosteroid.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040014',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease corticosteroid allergy ?',
#   'missing_words': array(['corticosteroid'], dtype=object),
#   'llm_response': "['corticosteroids']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'sulfonamide allergy',
#   'description': 'A drug allergy that has allergic trigger sulfonamide.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040015',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease sulfonamide allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Drug allergy']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'sulfonamide allergy',
#   'description': 'A drug allergy that has allergic trigger sulfonamide.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040015',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease sulfonamide allergy ?',
#   'missing_words': array(['sulfonamide'], dtype=object),
#   'llm_response': "['sulfonamide']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'sulfamethoxazole allergy',
#   'description': 'A drug allergy that has allergic trigger sulfamethoxazole.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040016',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease sulfamethoxazole allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction', 'Type I hypersensitivity reaction']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'sulfamethoxazole allergy',
#   'description': 'A drug allergy that has allergic trigger sulfamethoxazole.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040016',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease sulfamethoxazole allergy ?',
#   'missing_words': array(['sulfamethoxazole'], dtype=object),
#   'llm_response': "['sulfamethoxazole']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'suprofen allergy',
#   'description': 'A drug allergy that has allergic trigger suprofen.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040017',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease suprofen allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Hypersensitivity']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'suprofen allergy',
#   'description': 'A drug allergy that has allergic trigger suprofen.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040017',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease suprofen allergy ?',
#   'missing_words': array(['suprofen'], dtype=object),
#   'llm_response': "['Suprofen']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'thiopental allergy',
#   'description': 'A drug allergy that has allergic trigger thiopental.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040018',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease thiopental allergy ?',
#   'missing_words': array(['Drug'], dtype=object),
#   'llm_response': "['Anaphylactoid']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'thiopental allergy',
#   'description': 'A drug allergy that has allergic trigger thiopental.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040018',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease thiopental allergy ?',
#   'missing_words': array(['Thiopental'], dtype=object),
#   'llm_response': "['thiopental']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'D-mannitol allergy',
#   'description': 'A drug allergy that has allergic trigger D-mannitol.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040019',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease D-mannitol allergy ?',
#   'missing_words': array(['Drug'], dtype=object),
#   'llm_response': "['Oral Allergy Syndrome']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'D-mannitol allergy',
#   'description': 'A drug allergy that has allergic trigger D-mannitol.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040019',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease D-mannitol allergy ?',
#   'missing_words': array(['D-mannitol'], dtype=object),
#   'llm_response': "['D-mannitol']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'cefotaxime allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger cefotaxime.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040020',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease cefotaxime allergy ?',
#   'missing_words': array(['cephalosporin'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction', 'Allergic reaction', 'Type I hypersensitivity reaction']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'cefotaxime allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger cefotaxime.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040020',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease cefotaxime allergy ?',
#   'missing_words': array(['cefotaxime'], dtype=object),
#   'llm_response': "['Cefotaxime']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'cephalosporin allergy',
#   'description': 'A drug allergy that has allergic trigger cephalosporin.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040021',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease cephalosporin allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Penicillin allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'cephalosporin allergy',
#   'description': 'A drug allergy that has allergic trigger cephalosporin.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040021',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease cephalosporin allergy ?',
#   'missing_words': array(['cephalosporin'], dtype=object),
#   'llm_response': "['Penicillin']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'amodiaquine allergy',
#   'description': 'A drug allergy that has allergic trigger amodiaquine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040022',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease amodiaquine allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction', 'Type IV hypersensitivity']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'amodiaquine allergy',
#   'description': 'A drug allergy that has allergic trigger amodiaquine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040022',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease amodiaquine allergy ?',
#   'missing_words': array(['amodiaquine'], dtype=object),
#   'llm_response': "['4-Aminoquinoline']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'cefaclor allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger cefaclor.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040023',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease cefaclor allergy ?',
#   'missing_words': array(['Cephalosporin'], dtype=object),
#   'llm_response': "['Penicillin Allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'cefaclor allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger cefaclor.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040023',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease cefaclor allergy ?',
#   'missing_words': array(['Cefaclor'], dtype=object),
#   'llm_response': "['Cefaclor']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'ceftazidime allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger ceftazidime.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040024',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease ceftazidime allergy ?',
#   'missing_words': array(['cephalosporin'], dtype=object),
#   'llm_response': "['Penicillin allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'ceftazidime allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger ceftazidime.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040024',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease ceftazidime allergy ?',
#   'missing_words': array(['ceftazidime'], dtype=object),
#   'llm_response': "['Ceftazidime is a third-generation cephalosporin antibiotic, and the allergic trigger is likely the beta-lactam ring or the side chain of the molecule, but the exact trigger is often the side chain of the molecule, specifically the 7-alpha-methoxyimino group.']",
#   'score': 1,
#   'llm_response_opinion': 0},
#  {'entity': 'cefuroxime allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger cefuroxime.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040025',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease cefuroxime allergy ?',
#   'missing_words': array(['cephalosporin'], dtype=object),
#   'llm_response': "['Penicillin allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'cefuroxime allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger cefuroxime.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040025',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease cefuroxime allergy ?',
#   'missing_words': array(['cefuroxime'], dtype=object),
#   'llm_response': "['Cefuroxime']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'chlorhexidine allergy',
#   'description': 'A drug allergy that has allergic trigger chlorhexidine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040026',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease chlorhexidine allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Contact dermatitis']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'chlorhexidine allergy',
#   'description': 'A drug allergy that has allergic trigger chlorhexidine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040026',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease chlorhexidine allergy ?',
#   'missing_words': array(['chlorhexidine'], dtype=object),
#   'llm_response': "['Chlorhexidine']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'cyclophosphamide allergy',
#   'description': 'A drug allergy that has allergic trigger cyclophosphamide.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040027',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease cyclophosphamide allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Chemical allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'cyclophosphamide allergy',
#   'description': 'A drug allergy that has allergic trigger cyclophosphamide.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040027',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease cyclophosphamide allergy ?',
#   'missing_words': array(['cyclophosphamide'], dtype=object),
#   'llm_response': "['Cyclophosphamide']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'succinylcholine allergy',
#   'description': 'A drug allergy that has allergic trigger succinylcholine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040028',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease succinylcholine allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Muscarinic and nicotinic acetylcholine receptor hypersensitivity']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'succinylcholine allergy',
#   'description': 'A drug allergy that has allergic trigger succinylcholine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040028',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease succinylcholine allergy ?',
#   'missing_words': array(['succinylcholine'], dtype=object),
#   'llm_response': "['Succinylcholine']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'trimethoprim allergy',
#   'description': 'A drug allergy that has allergic trigger trimethoprim.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040029',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease trimethoprim allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction', 'Allergic reaction', 'Type B hypersensitivity reaction']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'trimethoprim allergy',
#   'description': 'A drug allergy that has allergic trigger trimethoprim.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040029',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease trimethoprim allergy ?',
#   'missing_words': array(['trimethoprim'], dtype=object),
#   'llm_response': "['Trimethoprim']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'cefixime allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger cefixime.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040030',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease cefixime allergy ?',
#   'missing_words': array(['Cephalosporin'], dtype=object),
#   'llm_response': "['Penicillin allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'cefixime allergy',
#   'description': 'A cephalosporin allergy that has allergic trigger cefixime.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040030',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease cefixime allergy ?',
#   'missing_words': array(['Cefixime'], dtype=object),
#   'llm_response': "['Cefixime']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'diclofenac allergy',
#   'description': 'A drug allergy that has allergic trigger diclofenac.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040031',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease diclofenac allergy ?',
#   'missing_words': array(['Drug'], dtype=object),
#   'llm_response': "['Drug allergy']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'diclofenac allergy',
#   'description': 'A drug allergy that has allergic trigger diclofenac.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040031',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease diclofenac allergy ?',
#   'missing_words': array(['Diclofenac'], dtype=object),
#   'llm_response': "['Diclofenac']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'carbapenem allergy',
#   'description': 'A drug allergy that has allergic trigger carbapenems.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040032',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease carbapenem allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Penicillin allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'carbapenem allergy',
#   'description': 'A drug allergy that has allergic trigger carbapenems.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040032',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease carbapenem allergy ?',
#   'missing_words': array(['carbapenems'], dtype=object),
#   'llm_response': "['Carbapenems']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'piperacillin allergy',
#   'description': 'A beta-lactam allergy that has allergic trigger piperacillin.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040033',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease piperacillin allergy ?',
#   'missing_words': array(['beta-lactam'], dtype=object),
#   'llm_response': "['Penicillin allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'piperacillin allergy',
#   'description': 'A beta-lactam allergy that has allergic trigger piperacillin.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040033',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease piperacillin allergy ?',
#   'missing_words': array(['piperacillin'], dtype=object),
#   'llm_response': "['Piperacillin', 'Penicillin']",
#   'score': 1,
#   'llm_response_opinion': 0},
#  {'entity': 'rocuronium allergy',
#   'description': 'A drug allergy that has allergic trigger rocuronium.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040034',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease rocuronium allergy ?',
#   'missing_words': array(['Drug'], dtype=object),
#   'llm_response': "['Muscle relaxant allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'rocuronium allergy',
#   'description': 'A drug allergy that has allergic trigger rocuronium.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040034',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease rocuronium allergy ?',
#   'missing_words': array(['Rocuronium'], dtype=object),
#   'llm_response': "['Rocuronium']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'sulfasalazine allergy',
#   'description': 'A drug allergy that has allergic trigger sulfasalazine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040035',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease sulfasalazine allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Drug allergy']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'sulfasalazine allergy',
#   'description': 'A drug allergy that has allergic trigger sulfasalazine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040035',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease sulfasalazine allergy ?',
#   'missing_words': array(['sulfasalazine'], dtype=object),
#   'llm_response': "['Sulfonamide']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'tubocurarine allergy',
#   'description': 'A drug allergy that has allergic trigger tubocurarine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040036',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease tubocurarine allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Anaphylactic allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'tubocurarine allergy',
#   'description': 'A drug allergy that has allergic trigger tubocurarine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040036',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease tubocurarine allergy ?',
#   'missing_words': array(['tubocurarine'], dtype=object),
#   'llm_response': "['tubocurarine']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'aztreonam allergy',
#   'description': 'A beta-lactam allergy that has allergic trigger aztreonam.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040037',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease aztreonam allergy ?',
#   'missing_words': array(['beta-lactam'], dtype=object),
#   'llm_response': "['Penicillin allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'aztreonam allergy',
#   'description': 'A beta-lactam allergy that has allergic trigger aztreonam.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040037',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease aztreonam allergy ?',
#   'missing_words': array(['aztreonam'], dtype=object),
#   'llm_response': "['Penicillin']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'meropenem allergy',
#   'description': 'An allergic asthma that has allergic trigger meropenem, a beta-lactam antibiotic.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040038',
#   'red_herring': False,
#   'query': 'What type of asthma is associated with the disease meropenem allergy ?',
#   'missing_words': array(['allergic'], dtype=object),
#   'llm_response': "['Allergic Bronchopulmonary Aspergillosis (ABPA)']",
#   'score': 1,
#   'llm_response_opinion': 0},
#  {'entity': 'meropenem allergy',
#   'description': 'An allergic asthma that has allergic trigger meropenem, a beta-lactam antibiotic.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040038',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease meropenem allergy ?',
#   'missing_words': array(['meropenem'], dtype=object),
#   'llm_response': "['Penicillin', 'Beta-lactam']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'quinidine allergy',
#   'description': 'A drug allergy that has allergic trigger quinidine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040065',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease quinidine allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Drug allergy']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'quinidine allergy',
#   'description': 'A drug allergy that has allergic trigger quinidine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040065',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease quinidine allergy ?',
#   'missing_words': array(['quinidine'], dtype=object),
#   'llm_response': "['quinidine']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'melphalan allergy',
#   'description': 'A drug allergy that has allergic trigger melphalan.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040066',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease melphalan allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Chemical allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'melphalan allergy',
#   'description': 'A drug allergy that has allergic trigger melphalan.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040066',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease melphalan allergy ?',
#   'missing_words': array(['melphalan'], dtype=object),
#   'llm_response': "['Melphalan']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'co-trimoxazole allergy',
#   'description': 'A drug allergy that has allergic trigger co-trimoxazole.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040070',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease co-trimoxazole allergy ?',
#   'missing_words': array(['Drug'], dtype=object),
#   'llm_response': "['Hypersensitivity reaction', 'Type IV hypersensitivity']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'co-trimoxazole allergy',
#   'description': 'A drug allergy that has allergic trigger co-trimoxazole.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040070',
#   'red_herring': False,
#   'query': 'What is the allergic trigger for the disease co-trimoxazole allergy ?',
#   'missing_words': array(['Co-trimoxazole'], dtype=object),
#   'llm_response': "['Sulfonamides']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'gallamine allergy',
#   'description': 'A drug allergy that has allergic trigger gallamine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040078',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease gallamine allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Muscarinic acetylcholine receptor allergy']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'gallamine allergy',
#   'description': 'A drug allergy that has allergic trigger gallamine.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040078',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease gallamine allergy ?',
#   'missing_words': array(['gallamine'], dtype=object),
#   'llm_response': "['Gallamine']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'oxirane allergy',
#   'description': 'A drug allergy that has allergic trigger oxirane.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040082',
#   'red_herring': False,
#   'query': 'What type of allergy is the disease oxirane allergy ?',
#   'missing_words': array(['drug'], dtype=object),
#   'llm_response': "['Contact dermatitis']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'oxirane allergy',
#   'description': 'A drug allergy that has allergic trigger oxirane.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040082',
#   'red_herring': False,
#   'query': 'What is the allergic trigger in the disease oxirane allergy ?',
#   'missing_words': array(['oxirane'], dtype=object),
#   'llm_response': "['oxirane']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'Chlamydia pneumonia',
#   'description': 'A bacterial pneumonia has material basis in Chlamydia pneumoniae.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040083',
#   'red_herring': False,
#   'query': 'What type of pneumonia is the disease Chlamydia pneumonia ?',
#   'missing_words': array(['bacterial'], dtype=object),
#   'llm_response': "['atypical pneumonia']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'Chlamydia pneumonia',
#   'description': 'A bacterial pneumonia has material basis in Chlamydia pneumoniae.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040083',
#   'red_herring': False,
#   'query': 'What is the causative agent of the disease Chlamydia pneumonia ?',
#   'missing_words': array(['Chlamydia'], dtype=object),
#   'llm_response': "['Chlamydophila pneumoniae']",
#   'score': 0,
#   'llm_response_opinion': 1},
#  {'entity': 'Streptococcus pneumonia',
#   'description': 'A bacterial pneumonia has material basis in Streptococcus pneumoniae.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040084',
#   'red_herring': False,
#   'query': 'What type of organism causes the disease Streptococcus pneumonia?',
#   'missing_words': array(['Bacterial'], dtype=object),
#   'llm_response': "['Bacteria']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'Streptococcus pneumonia',
#   'description': 'A bacterial pneumonia has material basis in Streptococcus pneumoniae.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040084',
#   'red_herring': False,
#   'query': 'What is the causative agent of the disease Streptococcus pneumonia?',
#   'missing_words': array(['Streptococcus'], dtype=object),
#   'llm_response': "['Streptococcus pneumoniae']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'bacterial sepsis',
#   'description': 'A bacterial infectious disease has material basis in Bacteria.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040085',
#   'red_herring': False,
#   'query': 'What type of infectious disease is the disease bacterial sepsis ?',
#   'missing_words': array(['Bacterial'], dtype=object),
#   'llm_response': "['Bacterial sepsis is a type of bacterial infection.']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'bacterial sepsis',
#   'description': 'A bacterial infectious disease has material basis in Bacteria.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040085',
#   'red_herring': False,
#   'query': 'What is the material basis of the disease bacterial sepsis ?',
#   'missing_words': array(['Bacteria'], dtype=object),
#   'llm_response': "['Bacteria']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'Polyomavirus-associated nephropathy',
#   'description': 'A viral infectious disease has material basis in BK polyomavirus.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040086',
#   'red_herring': False,
#   'query': 'What type of infectious agent is responsible for the disease Polyomavirus-associated nephropathy ?',
#   'missing_words': array(['Viral'], dtype=object),
#   'llm_response': "['Polyomavirus']",
#   'score': 0,
#   'llm_response_opinion': 1},
#  {'entity': 'Polyomavirus-associated nephropathy',
#   'description': 'A viral infectious disease has material basis in BK polyomavirus.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040086',
#   'red_herring': False,
#   'query': 'What is the material basis in the disease Polyomavirus-associated nephropathy ?',
#   'missing_words': array(['BK'], dtype=object),
#   'llm_response': "['DNA']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'autoimmune uveitis',
#   'description': 'An autoimmune disease of eyes, ear, nose and throat that is located in the uvea.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040088',
#   'red_herring': False,
#   'query': 'What type of disease is the disease autoimmune uveitis ?',
#   'missing_words': array(['autoimmune'], dtype=object),
#   'llm_response': "['Autoimmune', 'Inflammatory']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune uveitis',
#   'description': 'An autoimmune disease of eyes, ear, nose and throat that is located in the uvea.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040088',
#   'red_herring': False,
#   'query': 'Where is the disease autoimmune uveitis located ?',
#   'missing_words': array(['uvea'], dtype=object),
#   'llm_response': "['Eye']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'autoimmune gastritis',
#   'description': 'An autoimmune disease of gastrointestinal tract that is located in the stomach.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040090',
#   'red_herring': False,
#   'query': 'What type of disease is the disease autoimmune gastritis ?',
#   'missing_words': array(['Autoimmune'], dtype=object),
#   'llm_response': "['Autoimmune disease']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune gastritis',
#   'description': 'An autoimmune disease of gastrointestinal tract that is located in the stomach.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040090',
#   'red_herring': False,
#   'query': 'Where is the disease autoimmune gastritis located ?',
#   'missing_words': array(['Stomach'], dtype=object),
#   'llm_response': "['Stomach']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune pancreatitis',
#   'description': 'An autoimmune disease of endocrine system that is located in the pancreas.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040091',
#   'red_herring': False,
#   'query': 'What type of disease is the disease autoimmune pancreatitis ?',
#   'missing_words': array(['Autoimmune'], dtype=object),
#   'llm_response': "['Inflammatory', 'Autoimmune']",
#   'score': 0,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune pancreatitis',
#   'description': 'An autoimmune disease of endocrine system that is located in the pancreas.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040091',
#   'red_herring': False,
#   'query': 'Where is the disease autoimmune pancreatitis located ?',
#   'missing_words': array(['Pancreas'], dtype=object),
#   'llm_response': "['Pancreas']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune glomerulonephritis',
#   'description': 'An autoimmune disease of urogenital tract that is located in the renal glomerulus.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040094',
#   'red_herring': False,
#   'query': 'What type of disease is the disease autoimmune glomerulonephritis ?',
#   'missing_words': array(['autoimmune'], dtype=object),
#   'llm_response': "['Autoimmune disease', 'Glomerulonephritis']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune glomerulonephritis',
#   'description': 'An autoimmune disease of urogenital tract that is located in the renal glomerulus.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040094',
#   'red_herring': False,
#   'query': 'Where is the disease autoimmune glomerulonephritis located ?',
#   'missing_words': array(['glomerulus'], dtype=object),
#   'llm_response': "['Kidneys']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'autoimmune cardiomyopathy',
#   'description': 'An autoimmune disease of cardiovascular system that is characterized by deterioration of the function of the heart muscle.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040095',
#   'red_herring': False,
#   'query': 'What type of disease is the disease autoimmune cardiomyopathy ?',
#   'missing_words': array(['Autoimmune'], dtype=object),
#   'llm_response': "['Autoimmune disease']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune cardiomyopathy',
#   'description': 'An autoimmune disease of cardiovascular system that is characterized by deterioration of the function of the heart muscle.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040095',
#   'red_herring': False,
#   'query': 'What system does the disease autoimmune cardiomyopathy affect ?',
#   'missing_words': array(['Cardiovascular'], dtype=object),
#   'llm_response': "['cardiovascular']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune atherosclerosis',
#   'description': 'An autoimmune disease of cardiovascular system that is characterized by a build up of plaque in the arteries.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040096',
#   'red_herring': False,
#   'query': 'What type of disease is the disease autoimmune atherosclerosis ?',
#   'missing_words': array(['Autoimmune'], dtype=object),
#   'llm_response': "['Autoimmune disease', 'Vascular disease']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune atherosclerosis',
#   'description': 'An autoimmune disease of cardiovascular system that is characterized by a build up of plaque in the arteries.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040096',
#   'red_herring': False,
#   'query': 'What system is affected by the disease autoimmune atherosclerosis ?',
#   'missing_words': array(['Cardiovascular'], dtype=object),
#   'llm_response': "['cardiovascular']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune vasculitis',
#   'description': 'An autoimmune disease of cardiovascular system that is characterized by inflammation of the blood vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040097',
#   'red_herring': False,
#   'query': 'What type of disease is the disease autoimmune vasculitis ?',
#   'missing_words': array(['Autoimmune'], dtype=object),
#   'llm_response': "['Autoimmune disease', 'Vasculitis']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'autoimmune vasculitis',
#   'description': 'An autoimmune disease of cardiovascular system that is characterized by inflammation of the blood vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0040097',
#   'red_herring': False,
#   'query': 'What part of the body is affected by the disease autoimmune vasculitis ?',
#   'missing_words': array(['Vessels'], dtype=object),
#   'llm_response': "['Blood vessels']",
#   'score': 0,
#   'llm_response_opinion': 1},
#  {'entity': 'pemphigus gestationis',
# ...
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060343',
#   'red_herring': False,
#   'query': 'What type of medication use causes the disease glucocorticoid-induced osteoporosis ?',
#   'missing_words': array(['glucocorticoids'], dtype=object),
#   'llm_response': "['Glucocorticoids']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'glucocorticoid-induced osteoporosis',
#   'description': 'An osteoporosis caused by chronic glucocorticoid use. Glucocorticoids impair the replication, differentiation and function of osteoblasts and induce the apoptosis of mature osteoblasts and osteocytes; the also favor osteoclastogenesis leading to an increase in bone resorption.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060343',
#   'red_herring': False,
#   'query': 'What process is increased in the disease glucocorticoid-induced osteoporosis ?',
#   'missing_words': array(['resorption'], dtype=object),
#   'llm_response': "['bone resorption']",
#   'score': 0,
#   'llm_response_opinion': 1},
#  {'entity': 'bacillary angiomatosis',
#   'description': 'A bartonellosis that has material basis in Bartonella henselae or has material basis in Bartonella quintana. The disease is characterized by the proliferation of blood vessels, resulting in them forming tumour-like masses in the skin and other organs.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060345',
#   'red_herring': False,
#   'query': 'What type of bacteria is associated with the disease bacillary angiomatosis ?',
#   'missing_words': array(['Bartonella'], dtype=object),
#   'llm_response': "['Bartonella henselae']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'bacillary angiomatosis',
#   'description': 'A bartonellosis that has material basis in Bartonella henselae or has material basis in Bartonella quintana. The disease is characterized by the proliferation of blood vessels, resulting in them forming tumour-like masses in the skin and other organs.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060345',
#   'red_herring': False,
#   'query': 'What organ system is primarily affected by the disease bacillary angiomatosis ?',
#   'missing_words': array(['Skin'], dtype=object),
#   'llm_response': "['Lymphatic system']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'acrorenal syndrome',
#   'description': 'A syndrome characterized by limb defects, usually bilateral, like cleft hands or feet and longitudinal defects involving radius or ulna, tibia or fibula and renal anomalies which include agenesis, hypoplasia and rarely polycystic kidneys. Additional malformations may involve the oro-mandibular region, the trachea and lungs, skin derivatives including sweat glands, mammary glands, the uterus, vas deferens, the nasal placodes and the eyes.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060347',
#   'red_herring': False,
#   'query': 'What type of limb defects are usually associated with the disease acrorenal syndrome ?',
#   'missing_words': array(['bilateral'], dtype=object),
#   'llm_response': "['Polysyndactyly', 'Polydactyly', 'Bilateral renal agenesis', 'Bilateral limb abnormalities']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'acrorenal syndrome',
#   'description': 'A syndrome characterized by limb defects, usually bilateral, like cleft hands or feet and longitudinal defects involving radius or ulna, tibia or fibula and renal anomalies which include agenesis, hypoplasia and rarely polycystic kidneys. Additional malformations may involve the oro-mandibular region, the trachea and lungs, skin derivatives including sweat glands, mammary glands, the uterus, vas deferens, the nasal placodes and the eyes.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060347',
#   'red_herring': False,
#   'query': 'What type of renal anomalies are rarely associated with the disease acrorenal syndrome ?',
#   'missing_words': array(['polycystic'], dtype=object),
#   'llm_response': "['Polycystic Kidney Disease', 'Renal Agenesis', 'Horseshoe Kidney']",
#   'score': 1,
#   'llm_response_opinion': 0},
#  {'entity': 'hypoparathyroidism-retardation-dysmorphism syndrome',
#   'description': 'A syndrome characterized by permanent parathyroid hormone (PTH) deficiency, hypocalcemia, hyperphosphatemia, facial anomalies, and psychomotor retardation that has material basis in homozygous or compound heterozygous mutation in the TBCE gene on chromosome 1q42.3.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060348',
#   'red_herring': False,
#   'query': 'What hormone deficiency characterizes the disease hypoparathyroidism-retardation-dysmorphism syndrome ?',
#   'missing_words': array(['PTH'], dtype=object),
#   'llm_response': "['parathyroid hormone']",
#   'score': 0,
#   'llm_response_opinion': 1},
#  {'entity': 'hypoparathyroidism-retardation-dysmorphism syndrome',
#   'description': 'A syndrome characterized by permanent parathyroid hormone (PTH) deficiency, hypocalcemia, hyperphosphatemia, facial anomalies, and psychomotor retardation that has material basis in homozygous or compound heterozygous mutation in the TBCE gene on chromosome 1q42.3.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060348',
#   'red_herring': False,
#   'query': 'Which gene mutation is associated with the disease hypoparathyroidism-retardation-dysmorphism syndrome ?',
#   'missing_words': array(['TBCE'], dtype=object),
#   'llm_response': "['GATA3']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'Stormorken syndrome',
#   'description': 'A blood platelet disease characterized by thrombocytopathy, thrombocytopenia, mild anemia, asplenia, tubular aggregate myopathy, miosis, headache, and ichthyosis. It has material basis in heterozygous mutation in the STM1 gene on chromosome 11p15. It has an autosomal dominant inheritance pattern.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060354',
#   'red_herring': False,
#   'query': 'What type of inheritance pattern is associated with the disease Stormorken syndrome ?',
#   'missing_words': array(['autosomal'], dtype=object),
#   'llm_response': "['X-linked dominant inheritance pattern']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'Stormorken syndrome',
#   'description': 'A blood platelet disease characterized by thrombocytopathy, thrombocytopenia, mild anemia, asplenia, tubular aggregate myopathy, miosis, headache, and ichthyosis. It has material basis in heterozygous mutation in the STM1 gene on chromosome 11p15. It has an autosomal dominant inheritance pattern.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060354',
#   'red_herring': False,
#   'query': 'Which gene mutation is linked to the disease Stormorken syndrome ?',
#   'missing_words': array(['STM1'], dtype=object),
#   'llm_response': "['COL3A1']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'Vici syndrome',
#   'description': 'A syndrome characterized by callosal agenesis, cataracts, cardiomyopathy, combined immunodeficiency and hypopigmentation. It has material basis in mutation in the EPG5 gene on chromosome 18q12.3.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060356',
#   'red_herring': False,
#   'query': 'What gene mutation is associated with the disease Vici syndrome ?',
#   'missing_words': array(['EPG5'], dtype=object),
#   'llm_response': "['VRK1']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'Vici syndrome',
#   'description': 'A syndrome characterized by callosal agenesis, cataracts, cardiomyopathy, combined immunodeficiency and hypopigmentation. It has material basis in mutation in the EPG5 gene on chromosome 18q12.3.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060356',
#   'red_herring': False,
#   'query': 'On which chromosome is the mutation found in the disease Vici syndrome ?',
#   'missing_words': array(['18q12.3'], dtype=object),
#   'llm_response': "['X']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'Sakati-Nyhan syndrome',
#   'description': 'An acrocephalosyndactylia characterized by abnormalities in the bones of the legs, congenital heart defects and craniofacial defects and craniosynostosis. The patients suffer from cyanosis and other respiratory and breathing infections.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060359',
#   'red_herring': False,
#   'query': 'What type of defects are associated with the disease Sakati-Nyhan syndrome ?',
#   'missing_words': array(['congenital'], dtype=object),
#   'llm_response': "['Hypoplastic nails', 'Cataracts', 'Dental caries', 'Gingivitis', 'Hypoplastic enamel', 'Microdontia', 'Short stature', 'Intellectual disability', 'Seizures', 'Behavioral problems', 'Dysmorphic features']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'Sakati-Nyhan syndrome',
#   'description': 'An acrocephalosyndactylia characterized by abnormalities in the bones of the legs, congenital heart defects and craniofacial defects and craniosynostosis. The patients suffer from cyanosis and other respiratory and breathing infections.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060359',
#   'red_herring': False,
#   'query': 'What type of infections do patients suffer from in the disease Sakati-Nyhan syndrome ?',
#   'missing_words': array(['respiratory'], dtype=object),
#   'llm_response': "['Pneumocystis jirovecii pneumonia', 'Recurrent infections']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'Hennekam syndrome',
#   'description': 'A lymphatic system disease characterized by he presence of intestinal lymphangiectasia, mental retardation, and characteristic facial anomalies. It is inherited in an autosomal recessive pattern. Most individuals with Hennekam syndrome have characteristic facial abnormalities, such as a flat face with accompanying puffy eyelids and hypertelorism; the nasal bridge is typically flat and the ears are typically small. Congenital extremity and genital lymphedema is present in most patients.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060366',
#   'red_herring': False,
#   'query': 'What type of inheritance pattern is associated with the disease Hennekam syndrome ?',
#   'missing_words': array(['autosomal'], dtype=object),
#   'llm_response': "['Autosomal recessive inheritance']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'Hennekam syndrome',
#   'description': 'A lymphatic system disease characterized by he presence of intestinal lymphangiectasia, mental retardation, and characteristic facial anomalies. It is inherited in an autosomal recessive pattern. Most individuals with Hennekam syndrome have characteristic facial abnormalities, such as a flat face with accompanying puffy eyelids and hypertelorism; the nasal bridge is typically flat and the ears are typically small. Congenital extremity and genital lymphedema is present in most patients.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060366',
#   'red_herring': False,
#   'query': 'What system of the body is primarily affected by the disease Hennekam syndrome ?',
#   'missing_words': array(['lymphatic'], dtype=object),
#   'llm_response': "['Dermatological']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'acrofacial dysostosis',
#   'description': 'A hetergeneous dysostosis that is characterized by digital dysplasia, downslanted palpebral fissures, deafness and developmental delay, has material basis in mutation to the SF3B4 gene.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060379',
#   'red_herring': False,
#   'query': 'What gene mutation is the material basis for the disease acrofacial dysostosis ?',
#   'missing_words': array(['SF3B4'], dtype=object),
#   'llm_response': "['FGFR2']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'acrofacial dysostosis',
#   'description': 'A hetergeneous dysostosis that is characterized by digital dysplasia, downslanted palpebral fissures, deafness and developmental delay, has material basis in mutation to the SF3B4 gene.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060379',
#   'red_herring': False,
#   'query': 'What type of dysplasia characterizes the disease acrofacial dysostosis ?',
#   'missing_words': array(['Digital'], dtype=object),
#   'llm_response': "['Maxillofacial dysplasia']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'Chilblain lupus',
#   'description': 'A cutaneous form of systemic lupus erythermatosus that is characterized by painful nodular skin lesions precipitated by variation in temperatures, has material basis in autosomal dominant inheritance of mutation in the TREX1 gene.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060386',
#   'red_herring': False,
#   'query': 'What type of inheritance is associated with the disease Chilblain lupus ?',
#   'missing_words': array(['autosomal'], dtype=object),
#   'llm_response': "['X-linked dominant']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'Chilblain lupus',
#   'description': 'A cutaneous form of systemic lupus erythermatosus that is characterized by painful nodular skin lesions precipitated by variation in temperatures, has material basis in autosomal dominant inheritance of mutation in the TREX1 gene.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060386',
#   'red_herring': False,
#   'query': 'Which gene mutation is linked to the disease Chilblain lupus ?',
#   'missing_words': array(['TREX1'], dtype=object),
#   'llm_response': "['ITGAM']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'NFIA-related disorder',
#   'description': 'A syndrome that has material basis in heterozygous mutation in the NFIA gene on chromosome 1p31 and that is characterized by macrocephaly, seizures, developmental delay, dysmorphic features, ventriculomegaly, and hypotonia.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060409',
#   'red_herring': False,
#   'query': 'What genetic mutation is associated with the disease NFIA-related disorder ?',
#   'missing_words': array(['NFIA'], dtype=object),
#   'llm_response': "['NFIA']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'NFIA-related disorder',
#   'description': 'A syndrome that has material basis in heterozygous mutation in the NFIA gene on chromosome 1p31 and that is characterized by macrocephaly, seizures, developmental delay, dysmorphic features, ventriculomegaly, and hypotonia.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060409',
#   'red_herring': False,
#   'query': 'What is a common neurological symptom of the disease NFIA-related disorder ?',
#   'missing_words': array(['Seizures'], dtype=object),
#   'llm_response': "['Hydrocephalus']",
#   'score': 0,
#   'llm_response_opinion': 0},
#  {'entity': 'SATB2-associated syndrome',
#   'description': 'A syndrome that has material basis in genetic changes that affect the SATB2 gene and that is characterized by mild to severe intellectual disability, a delayed or absent ability to speak, severe speech anomalies, abnormalities of the palate, teeth anomalies, behavioral issues with or without bone or brain anomalies, and onset before age 2.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060428',
#   'red_herring': False,
#   'query': 'What gene is affected in the disease SATB2-associated syndrome ?',
#   'missing_words': array(['SATB2'], dtype=object),
#   'llm_response': "['SATB2']",
#   'score': 1,
#   'llm_response_opinion': 1},
#  {'entity': 'SATB2-associated syndrome',
#   'description': 'A syndrome that has material basis in genetic changes that affect the SATB2 gene and that is characterized by mild to severe intellectual disability, a delayed or absent ability to speak, severe speech anomalies, abnormalities of the palate, teeth anomalies, behavioral issues with or without bone or brain anomalies, and onset before age 2.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0060428',
#   'red_herring': False,
#   'query': 'At what age does the disease SATB2-associated syndrome typically onset ?',
#   'missing_words': array(['2'], dtype=object),
#   'llm_response': "['Early childhood']",
#   'score': 0,
#   'llm_response_opinion': 1},
#  ...]

# %%
# Scores BASED ON Fuzzy Match
scores = calculate_combined_scores(humando_parsed_1Q_completed_tg, score_type='score')
print("Based on EXACT scoring, we have:")
print(f"Known Entities    : {scores[2]}")
print(f"Uncertain Entities: {scores[1]}")
print(f"Unknown Entities  : {scores[0]}")
# Out:
# Based on EXACT scoring, we have:
# Known Entities    : 416
# Uncertain Entities: 1804
# Unknown Entities  : 2282

# %%
# Scores BASED ON GPT4o opinion
scores = calculate_combined_scores(humando_parsed_1Q_completed_tg, score_type='llm_response_opinion')
print("Based on EXACT scoring, we have:")
print(f"Known Entities    : {scores[2]}")
print(f"Uncertain Entities: {scores[1]}")
print(f"Unknown Entities  : {scores[0]}")
# Out:
# Based on EXACT scoring, we have:
# Known Entities    : 1170
# Uncertain Entities: 1947
# Unknown Entities  : 1385

# %%
# Red Herrings Only
rh = [record for record in humando_parsed_1Q_completed_tg if record['red_herring']==True]
# Scores:
scores = calculate_combined_scores(rh, 'llm_response_opinion')
print("Based on EXACT scoring, we have:")
print(f"Known Entities    : {scores[2]}")
print(f"Uncertain Entities: {scores[1]}")
print(f"Unknown Entities  : {scores[0]}")
# Out:
# Based on EXACT scoring, we have:
# Known Entities    : 33
# Uncertain Entities: 89
# Unknown Entities  : 78

# %%
# View red herrings it got right!

rh_correct = [record for record in humando_parsed_1Q_completed_tg if (record['red_herring']==True) and (record['score']==1)]
rh_correct[0:4]
# Out:
# [{'entity': 'black piedra',
#   'description': 'A superficial mycosis that is a superficial fungal infection of the hair shaft caused by Piedraia hortae, an ascomycetous fungus forming hard black nodules on the shafts of the scalp, beard, moustache and pubic hair.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_12711_rh',
#   'red_herring': True,
#   'query': 'What type of infection is the disease blakc piedra ?',
#   'missing_words': array(['fungal'], dtype=object),
#   'llm_response': "['Fungal']",
#   'score': 1},
#  {'entity': 'thyroid adenoma',
#   'description': 'An endocrine organ benign neoplasm that is located in the thyroid and derives from glandular epithelial cells.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_2891_rh',
#   'red_herring': True,
#   'query': 'What type of neoplasm is the disease thryoid adenoma ?',
#   'missing_words': array(['benign'], dtype=object),
#   'llm_response': "['Benign neoplasm']",
#   'score': 1},
#  {'entity': 'thyroid adenoma',
#   'description': 'An endocrine organ benign neoplasm that is located in the thyroid and derives from glandular epithelial cells.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_2891_rh',
#   'red_herring': True,
#   'query': 'Where is the disease adenoid thyrama located ?',
#   'missing_words': array(['thyroid'], dtype=object),
#   'llm_response': "['Thyroid gland']",
#   'score': 1},
#  {'entity': 'dysgerminoma',
#   'description': 'A germ cell cancer that derives from cells that give rise to egg cells.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_4441_rh',
#   'red_herring': True,
#   'query': 'What type of cancer is the disease dysgernimoma ?',
#   'missing_words': array(['Germ'], dtype=object),
#   'llm_response': "['germ cell tumor']",
#   'score': 1}]

# %%
# function to separate data into known and unknown entities

def filter_score_sets(data, score_type='score'):
    """
    Filter data into two sets based on combined scores per ID.
    
    Args:
        data (list): List of dictionaries containing query data with scores
        
    Returns:
        tuple: (perfect_scores, zero_scores) where each is a list of dictionaries
               containing unique id, entity, and description for entries with
               total scores of 2 and 0 respectively
    """
    # First, group by ID and calculate total scores
    grouped_scores = {}
    for item in data:
        if item['id'] not in grouped_scores:
            grouped_scores[item['id']] = {
                'total_score': 0,
                'entity': item['entity'],
                'description': item['description'],
                'id': item['id']
            }
        grouped_scores[item['id']]['total_score'] += item[score_type]
    
    # Filter into two sets
    perfect_scores = [
        {
            'id': info['id'],
            'entity': info['entity'],
            'description': info['description']
        }
        for info in grouped_scores.values()
        if info['total_score'] == 2
    ]
    
    zero_scores = [
        {
            'id': info['id'],
            'entity': info['entity'],
            'description': info['description']
        }
        for info in grouped_scores.values()
        if info['total_score'] == 0
    ]
    
    return perfect_scores, zero_scores

# %%
# The known and unknown entities are as follows:
import random

records_known, records_unknown = filter_score_sets(humando_parsed_1Q_completed_tg, score_type='llm_response_opinion')

entities_known_1Q  = [record['entity'] for record in records_known]
print("No. of known entities = ", len(entities_known_1Q))
print("Examples: ", random.sample(entities_known_1Q, 4))
print('\n')
entities_unknown_1Q = [record['entity'] for record in records_unknown]
print("No. of unknown entities = ", len(entities_unknown_1Q))
print("Examples: ", random.sample(entities_unknown_1Q, 4))
# Out:
# No. of known entities =  1170
# Examples:  ['Shwachman-Diamond syndrome', 'plantar wart', 'corneal argyrosis', 'Sjogren-Larsson syndrome']
#
#
# No. of unknown entities =  1385
# Examples:  ['monocular exotropia', 'cataract 7', 'follicular mucinosis', 'sphenoid sinusitis']

# %% [markdown]
# When using the previous dataset we had to remove duplicates, i.e. entities which appeared in both the known and unknown lists.
# That is not a concern with this Human DO dataset, so we cna skip that step and move directly to getting feature activations from Goodfire.
#
# Beware, slow process!

# %%
# Save progress

import csv

def save_list_to_file(data_list, filename):
    """
    Saves a list to a file, properly handling commas and special characters.
    
    Args:
        data_list (list): The list to save
        filename (str): Name of the output file
    """
    try:
        with open(filename, 'w', newline='', encoding='utf-8') as file:
            writer = csv.writer(file, quoting=csv.QUOTE_ALL)
            # Write each item as a row
            for item in data_list:
                writer.writerow([item])
        print(f"Successfully saved list to {filename}")
    except Exception as e:
        print(f"Error saving list: {e}")


# Apply save function
save_list_to_file(entities_known_1Q, '../classifier/data_classifier/entities_known_1Q.csv' )
save_list_to_file(entities_unknown_1Q, '../classifier/data_classifier/entities_unknown_1Q.csv' )
# Out:
# Successfully saved list to ../classifier/data_classifier_GPT4/entities_known_1Q.csv
# Successfully saved list to ../classifier/data_classifier_GPT4/entities_unknown_1Q.csv

# %%
def filter_dicts_by_entities(records, known_entities, unknown_entities):
    """
    Filters and transforms a list of dictionaries based on known and unknown entities.

    Args:
        records (list of dict): The original list of dictionaries to filter and transform.
        known_entities (list of str): A list of known entity names.
        unknown_entities (list of str): A list of unknown entity names.

    Returns:
        list of dict: The filtered and transformed list of dictionaries.
    """
    filtered_records = []

    for record in records:
        entity = record.get('entity')

        # Determine if the entity is in known or unknown lists
        if entity in known_entities:
            record['known_unknown'] = 'known'
        elif entity in unknown_entities:
            record['known_unknown'] = 'unknown'
        else:
            continue  # Skip records not matching either list

        # Transform the 'missing_words' key to 'answer_expected'
        if 'missing_words' in record:
            record['answer_expected'] = ' '.join(record.pop('missing_words'))

        # Transform the 'llm_response' key to a simple string
        if 'llm_response' in record:
            llm_response = record['llm_response']
            if isinstance(llm_response, str) and llm_response.startswith("[") and llm_response.endswith("]"):
                # Remove brackets and quotes, then strip
                record['llm_response'] = llm_response.strip("[]'\"")

        # Add the transformed record to the filtered list
        filtered_records.append(record)

    return filtered_records

# %%
queries_for_feature_extraction = filter_dicts_by_entities(humando_parsed_1Q_completed_tg, entities_known_1Q, entities_unknown_1Q)

# save to file
pd.DataFrame(queries_for_feature_extraction).to_parquet('../classifier/data_classifier/queries_for_feature_extraction.parquet')

# view examples
queries_for_feature_extraction[0:4]
# Out:
# [{'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'query': 'What type of cancer is the disease angiosarcoma ?',
#   'llm_response': 'Sarcoma',
#   'score': 0,
#   'known_unknown': 'unknown',
#   'answer_expected': 'Vascular'},
#  {'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'query': 'From which cells does the disease angiosarcoma derive ?',
#   'llm_response': 'endothelial cells',
#   'score': 0,
#   'known_unknown': 'unknown',
#   'answer_expected': 'Lining'},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'query': 'What type of disease is the disease pterygium ?',
#   'llm_response': "Ocular', 'Chronic', 'Degenerative",
#   'score': 0,
#   'known_unknown': 'unknown',
#   'answer_expected': 'corneal'},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'query': 'What type of tissue growth characterizes the disease pterygium ?',
#   'llm_response': 'fibrovascular',
#   'score': 0,
#   'known_unknown': 'unknown',
#   'answer_expected': 'triangular'}]

# %%
# Load progress

import pandas as pd

# load data
queries_for_feature_extraction = pd.read_parquet('../classifier/data_classifier/queries_for_feature_extraction.parquet' )

# convert from pandas to list of dicts
queries_for_feature_extraction = queries_for_feature_extraction.to_dict('records')

# insepct sample
queries_for_feature_extraction[0:4]
# Out:
# [{'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'query': 'What type of cancer is the disease angiosarcoma ?',
#   'llm_response': 'Sarcoma',
#   'score': 0,
#   'known_unknown': 'unknown',
#   'answer_expected': 'Vascular'},
#  {'entity': 'angiosarcoma',
#   'description': 'A vascular cancer that derives from the cells that line the walls of blood vessels or lymphatic vessels.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0001816',
#   'red_herring': False,
#   'query': 'From which cells does the disease angiosarcoma derive ?',
#   'llm_response': 'endothelial cells',
#   'score': 0,
#   'known_unknown': 'unknown',
#   'answer_expected': 'Lining'},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'query': 'What type of disease is the disease pterygium ?',
#   'llm_response': "Ocular', 'Chronic', 'Degenerative",
#   'score': 0,
#   'known_unknown': 'unknown',
#   'answer_expected': 'corneal'},
#  {'entity': 'pterygium',
#   'description': 'A corneal disease that is characterized by a triangular tissue growth located in cornea of the eye that is the result of collagen degeneration and fibrovascular proliferation.',
#   'id': 'http://purl.obolibrary.org/obo/DOID_0002116',
#   'red_herring': False,
#   'query': 'What type of tissue growth characterizes the disease pterygium ?',
#   'llm_response': 'fibrovascular',
#   'score': 0,
#   'known_unknown': 'unknown',
#   'answer_expected': 'triangular'}]

# %%
def get_feature_activations_v2(client, variant, entities, known_unknown_filter, key_name='query', k=100):
    """
    Processes a list of dictionaries, filtering by the 'known_unknown' key
    and operating on the 'key_name' key for feature activation retrieval, default to get features for the query
    
    Parameters:
    - client: The client to call the features API.
    - variant: The model variant to use.
    - entities: A list of dictionaries containing entity details.
    - known_unknown_filter: The value to filter by in the 'known_unknown' key ('known' or 'unknown').
    - key_name: string of key from the dict which will be sent to Goodfire to get features, default to 'query'
    - k: Number of top features to retrieve for each entity.

    Returns:
    - feature_activations: List of dictionaries with feature activations per entity.
    - feature_library: Set of unique features and their IDs.
    """
    feature_activations = []
    feature_library = set()

    # Filter entities by the 'known_unknown' key
    filtered_entities = [entity for entity in entities if entity.get('known_unknown') == known_unknown_filter]

    for record in tqdm(filtered_entities, desc="Processing entities"):
        try:
            item = record.get(key_name)
            if not item:
                print(f"Skipping item : {record}")
                continue
            
            inspector = client.features.inspect(
                [{"role": "user", "content": item}],
                model=variant,
            )

            # Prepare to collect activated features
            features = []

            for activation in inspector.top(k=k):
                
                # Keep our own library of all unique features and their IDs
                feature_library.add((activation.feature.uuid, activation.feature.label))

                # Record the feature ID and its activation value for this query
                features.append({'uuid': activation.feature.uuid, 'activation': activation.activation})

            feature_activations.append({
                'query': record.get('query'),
                'entity': record.get('entity'),
                'known_unknown': record.get('known_unknown'),
                'red_herring': record.get('red_herring'),
                'entity_features': features
            })

            time.sleep(0.25)  # Simple rate limiting

        except Exception as e:
            print(f"Failed to process entity: {str(e)}")
            continue

    return feature_activations, feature_library

# %%
import pandas as pd
import goodfire
import time
import asyncio
from tqdm import tqdm
from dotenv import load_dotenv
import os
import logging
from typing import List, Dict, Any
import pickle

load_dotenv()

# Set up logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(f'../classifier/logs/feature_extraction_{time.strftime("%Y%m%d")}.log'),
        logging.StreamHandler()
    ]
)
logger = logging.getLogger(__name__)

RATE_LIMIT = 100  # Adjust based on your API limits
BATCH_SIZE = 10   # Adjust based on your needs

class AsyncRateLimiter:
    def __init__(self, requests_per_minute: int):
        self.semaphore = asyncio.Semaphore(requests_per_minute)
        self.request_times: List[float] = []
        self.window_size = 60
        self.requests_per_minute = requests_per_minute
        self.lock = asyncio.Lock()
        logger.info(f"Initialized rate limiter with {requests_per_minute} rpm")

    async def acquire(self):
        while True:
            current_time = time.time()
            should_wait = False
            wait_time = 0

            async with self.lock:
                self.request_times = [t for t in self.request_times 
                                    if current_time - t < self.window_size]

                if len(self.request_times) >= self.requests_per_minute:
                    wait_time = self.request_times[0] + self.window_size - current_time
                    if wait_time > 0:
                        should_wait = True
                else:
                    self.request_times.append(current_time)
                    await self.semaphore.acquire()
                    return

            if should_wait:
                logger.info(f"Rate limit reached, waiting for {wait_time:.2f} seconds")
                await asyncio.sleep(wait_time)
                continue

    async def release(self):
        self.semaphore.release()

async def process_entity(
    client: goodfire.AsyncClient,
    variant: goodfire.Variant,
    record: Dict,
    key_name: str,
    k: int,
    rate_limiter: AsyncRateLimiter
) -> Dict:
    """Process a single entity with rate limiting"""
    try:
        item = record.get(key_name)
        if not item:
            logger.warning(f"Skipping item: {record}")
            return None

        await rate_limiter.acquire()
        try:
            inspector = await client.features.inspect(
                [{"role": "user", "content": item}],
                model=variant,
            )
            features = []

            for activation in inspector.top(k=k):
                features.append({
                    "uuid": activation.feature.uuid,
                    "activation": activation.activation,
                })

            return {
                "query": record.get("query"),
                "entity": record.get("entity"),
                "known_unknown": record.get("known_unknown"),
                "red_herring": record.get("red_herring"),
                "entity_features": features,
            }
        finally:
            await rate_limiter.release()

    except Exception as e:
        logger.error(f"Failed to process entity: {str(e)}")
        return None

async def get_feature_activations_v2(
    client: goodfire.AsyncClient,
    variant: goodfire.Variant,
    entities: pd.DataFrame,
    known_unknown_filter: str,
    key_name: str = "query",
    k: int = 100,
    batch_size: int = BATCH_SIZE
):
    """Process entities in batches with rate limiting"""
    rate_limiter = AsyncRateLimiter(RATE_LIMIT)
    feature_activations = []
    feature_library = set()

    # Filter entities
    filtered_entities = [
        entity for entity in entities
        if entity.get("known_unknown") == known_unknown_filter
    ]
    
    logger.info(f"Processing {len(filtered_entities)} entities")

    # Process in batches
    for i in tqdm(range(0, len(filtered_entities), batch_size)):
        batch = filtered_entities[i:i + batch_size]
        
        logger.info(f"Processing batch of {len(batch)} entities")
        tasks = [
            process_entity(client, variant, record, key_name, k, rate_limiter)
            for record in batch
        ]
        
        batch_results = await asyncio.gather(*tasks, return_exceptions=True)
        
        for result in batch_results:
            if isinstance(result, Exception):
                logger.error(f"Batch processing error: {str(result)}")
                continue
            if result:
                feature_activations.append(result)
                # Update feature library
                for feature in result["entity_features"]:
                    feature_library.add((feature["uuid"], feature['label']))  # Adjust if you need labels

    logger.info(f"Processed {len(feature_activations)} entities successfully")
    return feature_activations, feature_library

# %%
client_gf = goodfire.Client(api_key)
variant = "meta-llama/Meta-Llama-3.1-8B-Instruct"

# Get the activations for the known and unknown entities

feature_activations_known_1Q,   feature_library_known_1Q   = await get_feature_activations_v2(client_gf, 
                                                                                        variant, 
                                                                                        queries_for_feature_extraction, 
                                                                                        known_unknown_filter='known', 
                                                                                        key_name='query',
                                                                                        k=100)

# %%
feature_activations_unknown_1Q, feature_library_unknown_1Q = await get_feature_activations_v2(client_gf, 
                                                                                        variant, 
                                                                                        queries_for_feature_extraction, 
                                                                                        known_unknown_filter='unknown', 
                                                                                        key_name='query',
                                                                                        k=100)

# %%
# Save progress
import pickle

# Save feature activations
with open('../classifier/data_classifier/feature_activations_known_3Q.pkl', 'wb') as f:
    pickle.dump(feature_activations_known_1Q, f)

# Save feature library
with open('../classifier/data_classifier/feature_library_known_3Q.pkl', 'wb') as f:
    pickle.dump(feature_library_known_1Q, f)

# Save feature activations
with open('../classifier/data_classifier/feature_activations_unknown_3Q.pkl', 'wb') as f:
    pickle.dump(feature_activations_unknown_1Q, f)

# Save feature library
with open('../classifier/data_classifier/feature_library_unknown_3Q.pkl', 'wb') as f:
    pickle.dump(feature_library_unknown_1Q, f)

# %% [markdown]
# ## Load Progress

# %%
import pickle

# Load feature activations for known data
with open('../classifier/data_classifier/feature_activations_known_3Q.pkl', 'rb') as f:
    feature_activations_known_1Q = pickle.load(f)

# Load feature library for known data
with open('../classifier/data_classifier/feature_library_known_3Q.pkl', 'rb') as f:
    feature_library_known_1Q = pickle.load(f)

# Load feature activations for unknown data
with open('../classifier/data_classifier/feature_activations_unknown_3Q.pkl', 'rb') as f:
    feature_activations_unknown_1Q = pickle.load(f)

# Load feature library for unknown data
with open('../classifier/data_classifier/feature_library_unknown_3Q.pkl', 'rb') as f:
    feature_library_unknown_1Q = pickle.load(f)

# %%
# inspect example
list(feature_library_known_1Q)[0:2]
# Out:
# [(UUID('270592d7-ac09-4c3a-98ce-77678bcd76bb'),
#   'Subject as a field name or category header in structured data'),
#  (UUID('de8804e6-a996-45d0-aec8-65ac5cc8eb71'),
#   'Verbs related to systematic resource allocation or progression')]

# %%
from collections import defaultdict
from typing import List, Dict, Set, Tuple
from uuid import UUID

def analyze_feature_separation(
    feature_activations_known: List[Dict],
    feature_activations_unknown: List[Dict],
    feature_library_known: Set[Tuple[UUID, str]],
    feature_library_unknown: Set[Tuple[UUID, str]]
) -> List[Tuple[str, float, float, float]]:
    """
    Analyzes feature activation patterns between known and unknown entities.
    
    Returns list of tuples: (feature_label, known_fraction, unknown_fraction, separation_score)
    sorted by absolute separation score (highest to lowest)
    """
    # Convert feature libraries to dict for easier lookup
    known_labels = dict(feature_library_known)
    unknown_labels = dict(feature_library_unknown)
    
    # Count feature occurrences
    known_counts = defaultdict(int)
    unknown_counts = defaultdict(int)
    
    # Count total records
    n_known = len(feature_activations_known)
    n_unknown = len(feature_activations_unknown)
    
    # Count feature occurrences in known entities
    for record in feature_activations_known:
        for feature in record['entity_features']:
            known_counts[feature['uuid']] += 1
            
    # Count feature occurrences in unknown entities
    for record in feature_activations_unknown:
        for feature in record['entity_features']:
            unknown_counts[feature['uuid']] += 1
    
    # Get all unique features
    all_features = set(known_counts.keys()) | set(unknown_counts.keys())
    
    # Calculate fractions and separation scores
    results = []
    for feature_id in all_features:
        # Get feature label
        label = known_labels.get(feature_id) or unknown_labels.get(feature_id) or str(feature_id)
        
        # Calculate fractions
        known_fraction = known_counts[feature_id] / n_known if n_known > 0 else 0
        unknown_fraction = unknown_counts[feature_id] / n_unknown if n_unknown > 0 else 0
        
        # Calculate separation score (difference in occurrence rates)
        separation_score = known_fraction - unknown_fraction
        
        results.append((label, feature_id, known_fraction, unknown_fraction, separation_score))
    
    # Sort by absolute separation score (highest to lowest)
    results.sort(key=lambda x: abs(x[3]), reverse=True)
    
    return results

# %%
# use the function
results = analyze_feature_separation(
    feature_activations_known_1Q,
    feature_activations_unknown_1Q,
    feature_library_known_1Q,
    feature_library_unknown_1Q
)

# Convert to pandas for presentation
feature_separations = pd.DataFrame(results)
feature_separations.columns = ['label', 'feature_id', 'known_frac', 'unknown_frac', 'sep_score' ]

# %%
# Investigate features most exclusive to unknown entities

pd.set_option('display.max_colwidth', None)
feature_separations.sort_values(['known_frac','unknown_frac'], ascending=[True, False]).head(15)
# Out:
#                                                                                        label  \
# 467                                          Professional and technical terminology suffixes
# 637       Named chemical reactions and formal reagent nomenclature in synthesis descriptions
# 684                Connecting words and syntax in technical documentation and specifications
# 708                                            The user is requesting a detailed description
# 716                        The assistant is generating analytical how-does-it-work questions
# 722                    Version numbers in technical contexts, especially version comparisons
# 725                                          Direct questions addressed to a specific entity
# 738                           Explanation of procedures and mechanisms using 'way' and 'how'
# 758                                                          Formal definitive article usage
# 770  Scientific measurement and monitoring equipment being listed in technical documentation
# 800                                      Command verbs that initiate user requests to the AI
# 908                               Technical system component identifiers and reference codes
# 916             The start of definitional or comparative questions, especially 'What is the'
# 948              Grammatical particles and connectors in South and Southeast Asian languages
# 966                       structural components and their modification in technical contexts
#
#                                feature_id  known_frac  unknown_frac  sep_score
# 467  d2a0678c-fffa-415e-a7f2-91264124f3b2         0.0      0.026395  -0.026395
# 637  1bfcf5e7-943f-470c-9866-3a213b59e9a6         0.0      0.017167  -0.017167
# 684  5b964a8a-c5b2-49c7-99a0-fa566cebd803         0.0      0.015665  -0.015665
# 708  c53844b4-b7d0-4888-ba04-96c6adcfe908         0.0      0.015021  -0.015021
# 716  9668d37f-4351-4e0f-9a46-baa5727d60e5         0.0      0.014807  -0.014807
# 722  566b2823-96fa-47d2-a597-3bec18d45e20         0.0      0.014592  -0.014592
# 725  c4843514-11e0-402d-bac5-05058d8f37ac         0.0      0.014592  -0.014592
# 738  813aa3df-c44f-4de4-a78c-4fce68db8cf7         0.0      0.014378  -0.014378
# 758  78889363-87bf-47a3-be4a-54c8efb0d109         0.0      0.013734  -0.013734
# 770  40e914cb-3e4f-4f2d-b86d-f30fa1111bf3         0.0      0.013519  -0.013519
# 800  cbe50bda-0cce-46dd-b4ee-e3750b011766         0.0      0.012876  -0.012876
# 908  41c9b3e9-4563-4a6a-a4c0-4287782ec604         0.0      0.010300  -0.010300
# 916  5dc8c5d8-be6e-4be4-8c17-064427297645         0.0      0.010300  -0.010300
# 948  25b9a532-2712-4e27-90b9-31d0773dcca9         0.0      0.009871  -0.009871
# 966  4d32c221-6233-4ced-893c-cc2d75d6df02         0.0      0.009657  -0.009657

# %%
## First view highest separation scores.., note this is not same as exclusivity
pd.set_option('display.max_colwidth', None)
feature_separations.sort_values('sep_score', ascending=True).head(15)
# Out:
#                                                                              label  \
# 58                            Explanations of rare genetic disorders and syndromes
# 119    Transcription factors and genetic elements being defined in scientific text
# 32                            Medical condition name suffixes (-itis, -oma, -osis)
# 39                         Medical terminology fragments in clinical documentation
# 42            References to having or experiencing medical/psychological disorders
# 160                     The assistant is providing a formatted list or enumeration
# 90       Document structure and navigation elements in technical or academic texts
# 80                  Requests to analyze or describe properties and characteristics
# 102                               Disease mechanisms and pathogenesis explanations
# 137                                              The assistant needs clarification
# 92          Technical and academic word suffixes in non-English European languages
# 88                                       Male characters in transit or on journeys
# 133  Standardized technical identifiers and version nomenclature in specifications
# 89                    Abstract organizational concepts and categorical descriptors
# 103                        Connecting syllables in long scientific/technical terms
#
#                                feature_id  known_frac  unknown_frac  sep_score
# 58   1292651f-8c52-4863-acf8-615b472c95bf    0.299422      0.425322  -0.125900
# 119  3b9ee33d-b958-4ea4-a7de-608025f74baa    0.038150      0.155794  -0.117644
# 32   b391dcf0-2080-4c6b-863c-d5f6067b776b    0.660116      0.777468  -0.117352
# 39   32a7fd06-6926-4857-8c9e-e47bddfab3d0    0.546821      0.656652  -0.109832
# 42   7ac9f4da-3e62-48b8-8699-062101e362cb    0.559538      0.643133  -0.083595
# 160  fba31f1f-0b24-483a-98f2-cbb30c904a79    0.013873      0.096781  -0.082908
# 90   cd092e67-147c-4e1d-92ab-4c5011e15cd1    0.191908      0.267597  -0.075689
# 80   11b0e86e-7f26-4e73-be9a-61c4f3c70e35    0.236994      0.311373  -0.074379
# 102  34e0a79b-4d1a-4fd6-8f6d-6c3cb1371f47    0.122543      0.195923  -0.073379
# 137  2162df1e-1dc5-4558-8be8-58c1df227709    0.046243      0.118455  -0.072212
# 92   97c5bc47-1d0e-4346-a643-9749d28e2ee8    0.173410      0.244421  -0.071010
# 88   00321542-a361-4f82-a439-fa021808f69a    0.209249      0.278326  -0.069078
# 133  b842ff21-7e7c-4f08-b695-5e9b66b6d8a7    0.060116      0.123605  -0.063490
# 89   8e42dac9-2604-41a6-b002-c2b03a7c07de    0.208092      0.268884  -0.060792
# 103  da9fb379-fe7d-4fa8-953b-91dc06d7a6a7    0.135260      0.195923  -0.060663

# %% [markdown]
# # These features are interesting, being RLHF about known vs unknown...

# %%
# Let's investigate the unknown feature, feature_0
def find_entity_by_uuid(records_list, target_uuid):
    """
    Find unique entity names where the given UUID exists in entity_features
    
    Args:
        records_list (list): List of dictionaries containing entity records
        target_uuid (str or UUID): UUID to search for
        
    Returns:
        list: List of unique entity names that contain the target UUID
    """
    # Convert target_uuid to string for comparison if it's not already
    target_uuid_str = str(target_uuid)
    
    # Use a set for automatic deduplication
    matching_entities = set()
    
    for record in records_list:
        # Check each feature in entity_features
        for feature in record['entity_features']:
            if str(feature['uuid']) == target_uuid_str:
                matching_entities.add(record['entity'])
                break  # Found a match, no need to check other features
                
    # Convert set back to list for return
    return list(matching_entities)

# %%
def get_feature_object(uuid_feature, feature_activations_list, client, variant, print_uuid=False):
    entities = find_entity_by_uuid(feature_activations_list, uuid_feature)
    if not entities:
        raise ValueError(f"No entities found for UUID {uuid_feature}")
    
    feature_entity_name = entities[0]  # Add index bounds check here
    
    inspector = client.features.inspect(
        [{"role": "user", "content": feature_entity_name}],
        model=variant
    )

    feature = None
    for activation in inspector.top(k=100):
        if str(activation.feature.uuid) == uuid_feature:
            feature = activation.feature
            break
            
    if feature is None:
        raise ValueError(f"Feature not found for UUID {uuid_feature}")

    # Get neighbors of a feature
    neighbors =  client.features.neighbors(
        feature,
        model=variant,
        top_k=10
    )

    print ("Neighbouring Features for: ", feature.label)
    print(feature.uuid)
    print ("--------------------------")

    for neighbor in neighbors:
        print(neighbor.label)
        if print_uuid:
            print(neighbor.uuid)

    return feature

# %% [markdown]
# # Let's investigate the top differentiating features which may generalise:
#
# Bearing in mind we are interested in GENERALISED features which may indicate whether the entity is known or known:
#
# ### From the features activated by known / unknown ENTITIES:
# - "Nonsensical or potentially harmful input requiring clarification or rejection"
#     - 475a1ebc-1432-4f32-a8f8-f3398de51bec
#
# ### From the features activated by known / unknown QUERIES:
# - "The assistant needs clarification"
#     - 2162df1e-1dc5-4558-8be8-58c1df227709

# %%
# 'Nonsensical or potentially harmful input requiring clarification or rejection',

get_feature_object(
    '475a1ebc-1432-4f32-a8f8-f3398de51bec', 
    feature_activations_known_1Q,
    client,
    variant)
#
# Out:
# Neighbouring Features for:  Nonsensical or potentially harmful input requiring clarification or rejection
# 475a1ebc-1432-4f32-a8f8-f3398de51bec
# --------------------------
# Requests for 2000-word technical articles about industrial topics
# Suffixes and word parts that make terms sound fantastical or science-fiction-like
# Academic punctuation patterns in references and formal lists
# Text corruption and encoding artifacts
# Formal conversation openings and polite transitions in professional discourse
# Brand names and product names that get split across multiple tokens
# Korean language text generation tokens
# Visualizing and organizing spatial relationships and structures
# Common connecting words and question markers in non-English languages
# Substrings common in made-up or invalid words across languages
# Feature("Nonsensical or potentially harmful input requiring clarification or rejection")

# %%
#  The assistant needs clarification

feature = get_feature_object(
    '2162df1e-1dc5-4558-8be8-58c1df227709', 
    feature_activations_known_1Q,
    client,
    variant, 
    print_uuid=False
    )
# Out:
# Neighbouring Features for:  The assistant needs clarification
# 2162df1e-1dc5-4558-8be8-58c1df227709
# --------------------------
# The user needs technical clarification
# Computer ports and connection interfaces
# European business address components, particularly Dutch and German
# Requests for 2000-word technical articles about industrial topics
# Punctuation in formal business entity names
# Property assignment linking words (is/of) in descriptive contexts
# The user has a question
# Domain-specific information queries in professional or technical contexts
# Grammatical transitions and connective elements in text
# Closing quotation marks in structured output

# %% [markdown]
# One feature appears on both lists:
#
# "Requests for 2000-word technical articles about industrial topics"

# %%
# Get neighbors of a feature
neighbors =  client.features.neighbors(feature,variant,10)
print(neighbors[3].label)
print(neighbors[3].uuid)
client.features.neighbors(neighbors[3],variant,10)
# Out:
# Requests for 2000-word technical articles about industrial topics
# b0226353-caf5-41e8-a645-888e6ff42100
# FeatureGroup([
#    0: "Nonsensical or potentially harmful input requiring clarification or rejection",
#    1: "European business address components, particularly Dutch and German",
#    2: "Academic punctuation patterns in references and formal lists",
#    3: "Computer ports and connection interfaces",
#    4: "Visualizing and organizing spatial relationships and structures",
#    5: "Standardized technical identifiers and version nomenclature in specifications",
#    6: "Offensive request from the user",
#    7: "Technical analysis and evaluation activities",
#    8: "Technical discussions of structure and dimensions in programming",
#    9: "Technical documentation requests about industrial processes and safety"
# ])

# %% [markdown]
# ### Scatter Graph

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 6))

# Plot all points in blue
plt.scatter(feature_separations['known_frac'], 
           feature_separations['unknown_frac'], 
           alpha=0.5, 
           color='blue', 
           label='Regular points')

# Get indices of top 10 lowest and highest sep_scores
lowest_scores_idx = feature_separations['sep_score'].nsmallest(5).index
highest_scores_idx = feature_separations['sep_score'].nlargest(5).index

# Highlight lowest scores in red
plt.scatter(feature_separations.loc[lowest_scores_idx, 'known_frac'],
           feature_separations.loc[lowest_scores_idx, 'unknown_frac'],
           color='red',
           s=100,
           label='10 lowest sep_scores')

# Highlight highest scores in green
plt.scatter(feature_separations.loc[highest_scores_idx, 'known_frac'],
           feature_separations.loc[highest_scores_idx, 'unknown_frac'],
           color='green',
           s=100,
           label='10 highest sep_scores')

plt.xlabel('Known Fraction')
plt.ylabel('Unknown Fraction')
plt.title('Feature Separation Scatter Plot')
plt.legend()

# Add label annotations for both sets of highlighted points
for idx in lowest_scores_idx:

    plt.annotate(feature_separations.loc[idx, 'label'],
                (feature_separations.loc[idx, 'known_frac'],
                 feature_separations.loc[idx, 'unknown_frac']),
                xytext=(5, 5), textcoords='offset points',
                color='red', fontsize=8)

for idx in highest_scores_idx:
    plt.annotate(feature_separations.loc[idx, 'label'],
                (feature_separations.loc[idx, 'known_frac'],
                 feature_separations.loc[idx, 'unknown_frac']),
                xytext=(5, 5), textcoords='offset points',
                color='green', fontsize=8)

plt.tight_layout()
plt.show()
